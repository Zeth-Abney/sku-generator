# %% [markdown]
# # SQLite Database Prototype
#
# > **⚠️ PORTFOLIO/DEMO CODE**
# > This notebook is preserved for portfolio purposes and uses `demo_prototype.db` instead of the production database.
# > The code is functional but isolated from the production `sku_catalog.db` file.
#
# This notebook designs and prototypes a SQLite database for the SKU generation system, with the intent to migrate to PostgreSQL on a Synology NAS in the future.
#
# ## Design Principles
# - Use SQLAlchemy ORM for database-agnostic code
# - Design schema to support future PostgreSQL migration
# - Maintain compatibility with existing Numbers-based workflow during transition

# %% [markdown]
# ## Phase 1: Schema Design
#
# ### Current Numbers File Structure (Reference)
#
# From `catalog.numbers`:
# - **Product_Catalog sheet**: Main product models with metadata
# - **Feature sheets**: Colors, Sizes, Designs, Materials, etc.
# - Each product has multiple features that create permutations
#
# ### Proposed Database Schema
#
# Below we'll design each table structure before implementation.

# %% [markdown]
# ## Phase 2: SQLite Implementation
#
# Now let's build the actual database using SQLAlchemy ORM.

# %% [markdown]
# ### Step 1: Import Dependencies
#
# We'll use SQLAlchemy for database-agnostic ORM code.

# %%
from sqlalchemy import create_engine, Column, Integer, String, Text, Numeric, Boolean, DateTime, ForeignKey, UniqueConstraint, Index
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker, relationship
from datetime import datetime
import os

print("SQLAlchemy imported successfully!")
# Out:
# SQLAlchemy imported successfully!

# %% [markdown]
# ### Step 2: Define Database Models
#
# These classes represent our 7 tables as SQLAlchemy ORM models.

# %%
# Create base class for all models
Base = declarative_base()

class Category(Base):
    __tablename__ = 'categories'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    category = Column(String(100), nullable=False)
    subcategory = Column(String(100))
    created_at = Column(DateTime, default=datetime.utcnow)
    updated_at = Column(DateTime, default=datetime.utcnow, onupdate=datetime.utcnow)
    
    # Relationships
    products = relationship("Product", back_populates="category")
    
    # Indexes
    __table_args__ = (
        Index('idx_category_subcategory', 'category', 'subcategory'),
    )
    
    def __repr__(self):
        return f"<Category(id={self.id}, category='{self.category}', subcategory='{self.subcategory}')>"


class Product(Base):
    __tablename__ = 'products'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    product_name = Column(String(200), nullable=False, unique=True)
    category_id = Column(Integer, ForeignKey('categories.id'))
    description = Column(Text)
    base_price = Column(Numeric(10, 2))
    status = Column(String(20), default='active')
    created_at = Column(DateTime, default=datetime.utcnow)
    updated_at = Column(DateTime, default=datetime.utcnow, onupdate=datetime.utcnow)
    
    # Relationships
    category = relationship("Category", back_populates="products")
    product_features = relationship("ProductFeature", back_populates="product")
    skus = relationship("SKU", back_populates="product")
    
    # Indexes
    __table_args__ = (
        Index('idx_product_name', 'product_name'),
        Index('idx_category_id', 'category_id'),
        Index('idx_status', 'status'),
    )
    
    def __repr__(self):
        return f"<Product(id={self.id}, name='{self.product_name}', status='{self.status}')>"


class FeatureType(Base):
    __tablename__ = 'feature_types'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    feature_type = Column(String(50), nullable=False, unique=True)
    display_order = Column(Integer)
    is_required = Column(Boolean, default=False)
    created_at = Column(DateTime, default=datetime.utcnow)
    
    # Relationships
    features = relationship("Feature", back_populates="feature_type")
    
    def __repr__(self):
        return f"<FeatureType(id={self.id}, type='{self.feature_type}', required={self.is_required})>"


class Feature(Base):
    __tablename__ = 'features'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    feature_type_id = Column(Integer, ForeignKey('feature_types.id'))
    code = Column(String(20), nullable=False)
    name = Column(String(100), nullable=False)
    description = Column(Text)
    sort_order = Column(Integer)
    is_active = Column(Boolean, default=True)
    created_at = Column(DateTime, default=datetime.utcnow)
    updated_at = Column(DateTime, default=datetime.utcnow, onupdate=datetime.utcnow)
    
    # Relationships
    feature_type = relationship("FeatureType", back_populates="features")
    product_features = relationship("ProductFeature", back_populates="feature")
    sku_features = relationship("SKUFeature", back_populates="feature")
    
    # Constraints and Indexes
    __table_args__ = (
        UniqueConstraint('feature_type_id', 'code', name='uq_feature_type_code'),
        Index('idx_feature_type_code', 'feature_type_id', 'code'),
        Index('idx_is_active', 'is_active'),
    )
    
    def __repr__(self):
        return f"<Feature(id={self.id}, code='{self.code}', name='{self.name}')>"


class ProductFeature(Base):
    __tablename__ = 'product_features'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    product_id = Column(Integer, ForeignKey('products.id'))
    feature_id = Column(Integer, ForeignKey('features.id'))
    created_at = Column(DateTime, default=datetime.utcnow)
    
    # Relationships
    product = relationship("Product", back_populates="product_features")
    feature = relationship("Feature", back_populates="product_features")
    
    # Constraints and Indexes
    __table_args__ = (
        UniqueConstraint('product_id', 'feature_id', name='uq_product_feature'),
        Index('idx_product_id', 'product_id'),
        Index('idx_feature_id', 'feature_id'),
    )
    
    def __repr__(self):
        return f"<ProductFeature(product_id={self.product_id}, feature_id={self.feature_id})>"


class SKU(Base):
    __tablename__ = 'skus'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    sku = Column(String(100), nullable=False, unique=True)
    product_id = Column(Integer, ForeignKey('products.id'))
    batch_name = Column(String(200))
    price = Column(Numeric(10, 2))
    inventory_qty = Column(Integer, default=0)
    status = Column(String(20), default='active')
    generated_at = Column(DateTime, default=datetime.utcnow)
    updated_at = Column(DateTime, default=datetime.utcnow, onupdate=datetime.utcnow)
    
    # Relationships
    product = relationship("Product", back_populates="skus")
    sku_features = relationship("SKUFeature", back_populates="sku")
    
    # Indexes
    __table_args__ = (
        Index('idx_sku', 'sku'),
        Index('idx_product_id_sku', 'product_id'),
        Index('idx_batch_name', 'batch_name'),
        Index('idx_status_sku', 'status'),
    )
    
    def __repr__(self):
        return f"<SKU(id={self.id}, sku='{self.sku}', status='{self.status}')>"


class SKUFeature(Base):
    __tablename__ = 'sku_features'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    sku_id = Column(Integer, ForeignKey('skus.id'))
    feature_id = Column(Integer, ForeignKey('features.id'))
    created_at = Column(DateTime, default=datetime.utcnow)
    
    # Relationships
    sku = relationship("SKU", back_populates="sku_features")
    feature = relationship("Feature", back_populates="sku_features")
    
    # Constraints and Indexes
    __table_args__ = (
        UniqueConstraint('sku_id', 'feature_id', name='uq_sku_feature'),
        Index('idx_sku_id', 'sku_id'),
        Index('idx_feature_id_sku', 'feature_id'),
    )
    
    def __repr__(self):
        return f"<SKUFeature(sku_id={self.sku_id}, feature_id={self.feature_id})>"

print("✓ All 7 database models defined successfully!")
# Out:
# ✓ All 7 database models defined successfully!
# /var/folders/qt/34m6wpbn699_75xmv603443m0000gn/T/ipykernel_55871/122878795.py:2: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %% [markdown]
# ### Step 3: Initialize the Database
#
# Create the SQLite database file and all tables.

# %%
# ⚠️ DEMO/PORTFOLIO CODE ONLY - Uses separate demo database
# Set database path to demo file (won't affect production sku_catalog.db)
DB_PATH = 'demo_prototype.db'

# Create engine (this is the connection to the database)
engine = create_engine(f'sqlite:///{DB_PATH}', echo=True)

# Create all tables defined in Base
Base.metadata.create_all(engine)

# Create session factory
Session = sessionmaker(bind=engine)

# Verify database was created
if os.path.exists(DB_PATH):
    db_size = os.path.getsize(DB_PATH)
    print(f"\n✓ Database created successfully!")
    print(f"  Location: {os.path.abspath(DB_PATH)}")
    print(f"  Size: {db_size} bytes")
    print(f"  Tables created: {len(Base.metadata.tables)}")
    print(f"  Table names: {list(Base.metadata.tables.keys())}")
else:
    print("✗ Database creation failed!")
# Out:
# 2025-12-02 14:40:11,379 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-02 14:40:11,380 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("categories")
# 2025-12-02 14:40:11,380 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-02 14:40:11,381 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("categories")
# 2025-12-02 14:40:11,381 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-02 14:40:11,381 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("products")
# 2025-12-02 14:40:11,381 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-02 14:40:11,382 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("products")
# 2025-12-02 14:40:11,382 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-02 14:40:11,382 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("feature_types")
# 2025-12-02 14:40:11,383 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-02 14:40:11,383 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("feature_types")
# 2025-12-02 14:40:11,383 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-02 14:40:11,383 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("features")
# 2025-12-02 14:40:11,384 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-02 14:40:11,384 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("features")
# 2025-12-02 14:40:11,384 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-02 14:40:11,384 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("product_features")
# 2025-12-02 14:40:11,385 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-02 14:40:11,385 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("product_features")
# 2025-12-02 14:40:11,385 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-02 14:40:11,385 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("skus")
# 2025-12-02 14:40:11,386 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-02 14:40:11,386 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("skus")
# 2025-12-02 14:40:11,386 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-02 14:40:11,386 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("sku_features")
# 2025-12-02 14:40:11,387 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-02 14:40:11,387 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("sku_features")
# 2025-12-02 14:40:11,387 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-02 14:40:11,388 INFO sqlalchemy.engine.Engine
# CREATE TABLE categories (
# 	id INTEGER NOT NULL,
# 	category VARCHAR(100) NOT NULL,
# 	subcategory VARCHAR(100),
# 	created_at DATETIME,
# 	updated_at DATETIME,
# 	PRIMARY KEY (id)
# )
#
#
# 2025-12-02 14:40:11,388 INFO sqlalchemy.engine.Engine [no key 0.00033s] ()
# 2025-12-02 14:40:11,389 INFO sqlalchemy.engine.Engine CREATE INDEX idx_category_subcategory ON categories (category, subcategory)
# 2025-12-02 14:40:11,389 INFO sqlalchemy.engine.Engine [no key 0.00025s] ()
# 2025-12-02 14:40:11,390 INFO sqlalchemy.engine.Engine
# CREATE TABLE feature_types (
# 	id INTEGER NOT NULL,
# 	feature_type VARCHAR(50) NOT NULL,
# 	display_order INTEGER,
# 	is_required BOOLEAN,
# 	created_at DATETIME,
# 	PRIMARY KEY (id),
# 	UNIQUE (feature_type)
# )
#
#
# 2025-12-02 14:40:11,390 INFO sqlalchemy.engine.Engine [no key 0.00012s] ()
# 2025-12-02 14:40:11,391 INFO sqlalchemy.engine.Engine
# CREATE TABLE products (
# 	id INTEGER NOT NULL,
# 	product_name VARCHAR(200) NOT NULL,
# 	category_id INTEGER,
# 	description TEXT,
# 	base_price NUMERIC(10, 2),
# 	status VARCHAR(20),
# 	created_at DATETIME,
# 	updated_at DATETIME,
# 	PRIMARY KEY (id),
# 	UNIQUE (product_name),
# 	FOREIGN KEY(category_id) REFERENCES categories (id)
# )
#
#
# 2025-12-02 14:40:11,391 INFO sqlalchemy.engine.Engine [no key 0.00017s] ()
# 2025-12-02 14:40:11,392 INFO sqlalchemy.engine.Engine CREATE INDEX idx_status ON products (status)
# 2025-12-02 14:40:11,392 INFO sqlalchemy.engine.Engine [no key 0.00014s] ()
# 2025-12-02 14:40:11,392 INFO sqlalchemy.engine.Engine CREATE INDEX idx_category_id ON products (category_id)
# 2025-12-02 14:40:11,393 INFO sqlalchemy.engine.Engine [no key 0.00024s] ()
# 2025-12-02 14:40:11,393 INFO sqlalchemy.engine.Engine CREATE INDEX idx_product_name ON products (product_name)
# 2025-12-02 14:40:11,393 INFO sqlalchemy.engine.Engine [no key 0.00018s] ()
# 2025-12-02 14:40:11,394 INFO sqlalchemy.engine.Engine
# CREATE TABLE features (
# 	id INTEGER NOT NULL,
# 	feature_type_id INTEGER,
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	description TEXT,
# 	sort_order INTEGER,
# 	is_active BOOLEAN,
# 	created_at DATETIME,
# 	updated_at DATETIME,
# 	PRIMARY KEY (id),
# 	CONSTRAINT uq_feature_type_code UNIQUE (feature_type_id, code),
# 	FOREIGN KEY(feature_type_id) REFERENCES feature_types (id)
# )
#
#
# 2025-12-02 14:40:11,395 INFO sqlalchemy.engine.Engine [no key 0.00029s] ()
# 2025-12-02 14:40:11,396 INFO sqlalchemy.engine.Engine CREATE INDEX idx_feature_type_code ON features (feature_type_id, code)
# 2025-12-02 14:40:11,396 INFO sqlalchemy.engine.Engine [no key 0.00025s] ()
# 2025-12-02 14:40:11,396 INFO sqlalchemy.engine.Engine CREATE INDEX idx_is_active ON features (is_active)
# 2025-12-02 14:40:11,397 INFO sqlalchemy.engine.Engine [no key 0.00016s] ()
# 2025-12-02 14:40:11,397 INFO sqlalchemy.engine.Engine
# CREATE TABLE product_features (
# 	id INTEGER NOT NULL,
# 	product_id INTEGER,
# 	feature_id INTEGER,
# 	created_at DATETIME,
# 	PRIMARY KEY (id),
# 	CONSTRAINT uq_product_feature UNIQUE (product_id, feature_id),
# 	FOREIGN KEY(product_id) REFERENCES products (id),
# 	FOREIGN KEY(feature_id) REFERENCES features (id)
# )
#
#
# 2025-12-02 14:40:11,397 INFO sqlalchemy.engine.Engine [no key 0.00017s] ()
# 2025-12-02 14:40:11,398 INFO sqlalchemy.engine.Engine CREATE INDEX idx_feature_id ON product_features (feature_id)
# 2025-12-02 14:40:11,398 INFO sqlalchemy.engine.Engine [no key 0.00026s] ()
# 2025-12-02 14:40:11,399 INFO sqlalchemy.engine.Engine CREATE INDEX idx_product_id ON product_features (product_id)
# 2025-12-02 14:40:11,399 INFO sqlalchemy.engine.Engine [no key 0.00023s] ()
# 2025-12-02 14:40:11,400 INFO sqlalchemy.engine.Engine
# CREATE TABLE skus (
# 	id INTEGER NOT NULL,
# 	sku VARCHAR(100) NOT NULL,
# 	product_id INTEGER,
# 	batch_name VARCHAR(200),
# 	price NUMERIC(10, 2),
# 	inventory_qty INTEGER,
# 	status VARCHAR(20),
# 	generated_at DATETIME,
# 	updated_at DATETIME,
# 	PRIMARY KEY (id),
# 	UNIQUE (sku),
# 	FOREIGN KEY(product_id) REFERENCES products (id)
# )
#
#
# 2025-12-02 14:40:11,400 INFO sqlalchemy.engine.Engine [no key 0.00018s] ()
# 2025-12-02 14:40:11,401 INFO sqlalchemy.engine.Engine CREATE INDEX idx_batch_name ON skus (batch_name)
# 2025-12-02 14:40:11,401 INFO sqlalchemy.engine.Engine [no key 0.00016s] ()
# 2025-12-02 14:40:11,402 INFO sqlalchemy.engine.Engine CREATE INDEX idx_product_id_sku ON skus (product_id)
# 2025-12-02 14:40:11,402 INFO sqlalchemy.engine.Engine [no key 0.00023s] ()
# 2025-12-02 14:40:11,403 INFO sqlalchemy.engine.Engine CREATE INDEX idx_status_sku ON skus (status)
# 2025-12-02 14:40:11,403 INFO sqlalchemy.engine.Engine [no key 0.00029s] ()
# 2025-12-02 14:40:11,404 INFO sqlalchemy.engine.Engine CREATE INDEX idx_sku ON skus (sku)
# 2025-12-02 14:40:11,404 INFO sqlalchemy.engine.Engine [no key 0.00017s] ()
# 2025-12-02 14:40:11,405 INFO sqlalchemy.engine.Engine
# CREATE TABLE sku_features (
# 	id INTEGER NOT NULL,
# 	sku_id INTEGER,
# 	feature_id INTEGER,
# 	created_at DATETIME,
# 	PRIMARY KEY (id),
# 	CONSTRAINT uq_sku_feature UNIQUE (sku_id, feature_id),
# 	FOREIGN KEY(sku_id) REFERENCES skus (id),
# 	FOREIGN KEY(feature_id) REFERENCES features (id)
# )
#
#
# 2025-12-02 14:40:11,405 INFO sqlalchemy.engine.Engine [no key 0.00016s] ()
# 2025-12-02 14:40:11,406 INFO sqlalchemy.engine.Engine CREATE INDEX idx_feature_id_sku ON sku_features (feature_id)
# 2025-12-02 14:40:11,406 INFO sqlalchemy.engine.Engine [no key 0.00015s] ()
# 2025-12-02 14:40:11,407 INFO sqlalchemy.engine.Engine CREATE INDEX idx_sku_id ON sku_features (sku_id)
# 2025-12-02 14:40:11,407 INFO sqlalchemy.engine.Engine [no key 0.00016s] ()
# 2025-12-02 14:40:11,410 INFO sqlalchemy.engine.Engine COMMIT
#
# ✓ Database created successfully!
#   Location: /Users/zethu/GitHub/sku-generator/sku_catalog.db
#   Size: 114688 bytes
#   Tables created: 7
#   Table names: ['categories', 'products', 'feature_types', 'features', 'product_features', 'skus', 'sku_features']

# %% [markdown]
# ### Step 4: Verify Database Schema
#
# Let's inspect the database structure to confirm everything was created correctly.

# %%
import sqlite3

# Connect to the database to inspect schema
conn = sqlite3.connect(DB_PATH)
cursor = conn.cursor()

# Get list of all tables
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

print("Database Tables:")
print("=" * 60)
for table in tables:
    table_name = table[0]
    print(f"\n{table_name.upper()}")
    print("-" * 60)
    
    # Get columns for this table
    cursor.execute(f"PRAGMA table_info({table_name});")
    columns = cursor.fetchall()
    
    for col in columns:
        col_id, name, col_type, not_null, default, pk = col
        pk_marker = " [PK]" if pk else ""
        null_marker = " NOT NULL" if not_null else ""
        default_marker = f" DEFAULT {default}" if default else ""
        print(f"  {name:<20} {col_type:<15}{pk_marker}{null_marker}{default_marker}")
    
    # Get indexes for this table
    cursor.execute(f"PRAGMA index_list({table_name});")
    indexes = cursor.fetchall()
    if indexes:
        print(f"\n  Indexes:")
        for idx in indexes:
            idx_name = idx[1]
            print(f"    - {idx_name}")

conn.close()
print("\n" + "=" * 60)
print("✓ Schema verification complete!")
# Out:
# Database Tables:
# ============================================================
#
# CATEGORIES
# ------------------------------------------------------------
#   id                   INTEGER         [PK] NOT NULL
#   category             VARCHAR(100)    NOT NULL
#   subcategory          VARCHAR(100)
#   created_at           DATETIME
#   updated_at           DATETIME
#
#   Indexes:
#     - idx_category_subcategory
#
# FEATURE_TYPES
# ------------------------------------------------------------
#   id                   INTEGER         [PK] NOT NULL
#   feature_type         VARCHAR(50)     NOT NULL
#   display_order        INTEGER
#   is_required          BOOLEAN
#   created_at           DATETIME
#
#   Indexes:
#     - sqlite_autoindex_feature_types_1
#
# PRODUCTS
# ------------------------------------------------------------
#   id                   INTEGER         [PK] NOT NULL
#   product_name         VARCHAR(200)    NOT NULL
#   category_id          INTEGER
#   description          TEXT
#   base_price           NUMERIC(10, 2)
#   status               VARCHAR(20)
#   created_at           DATETIME
#   updated_at           DATETIME
#
#   Indexes:
#     - idx_product_name
#     - idx_category_id
#     - idx_status
#     - sqlite_autoindex_products_1
#
# FEATURES
# ------------------------------------------------------------
#   id                   INTEGER         [PK] NOT NULL
#   feature_type_id      INTEGER
#   code                 VARCHAR(20)     NOT NULL
#   name                 VARCHAR(100)    NOT NULL
#   description          TEXT
#   sort_order           INTEGER
#   is_active            BOOLEAN
#   created_at           DATETIME
#   updated_at           DATETIME
#
#   Indexes:
#     - idx_is_active
#     - idx_feature_type_code
#     - sqlite_autoindex_features_1
#
# PRODUCT_FEATURES
# ------------------------------------------------------------
#   id                   INTEGER         [PK] NOT NULL
#   product_id           INTEGER
#   feature_id           INTEGER
#   created_at           DATETIME
#
#   Indexes:
#     - idx_product_id
#     - idx_feature_id
#     - sqlite_autoindex_product_features_1
#
# SKUS
# ------------------------------------------------------------
#   id                   INTEGER         [PK] NOT NULL
#   sku                  VARCHAR(100)    NOT NULL
#   product_id           INTEGER
#   batch_name           VARCHAR(200)
#   price                NUMERIC(10, 2)
#   inventory_qty        INTEGER
#   status               VARCHAR(20)
#   generated_at         DATETIME
#   updated_at           DATETIME
#
#   Indexes:
#     - idx_sku
#     - idx_status_sku
#     - idx_product_id_sku
#     - idx_batch_name
#     - sqlite_autoindex_skus_1
#
# SKU_FEATURES
# ------------------------------------------------------------
#   id                   INTEGER         [PK] NOT NULL
#   sku_id               INTEGER
#   feature_id           INTEGER
#   created_at           DATETIME
#
#   Indexes:
#     - idx_sku_id
#     - idx_feature_id_sku
#     - sqlite_autoindex_sku_features_1
#
# ============================================================
# ✓ Schema verification complete!

# %% [markdown]
# ### Step 5: Test with Sample Data
#
# Let's insert some test data to make sure everything works.

# %%
# Create a new session
session = Session()

try:
    # Create a test category
    test_category = Category(
        category="Apparel",
        subcategory="T-Shirts"
    )
    session.add(test_category)
    session.flush()  # Get the ID without committing
    
    # Create a test product
    test_product = Product(
        product_name="Test Basic Tee",
        category_id=test_category.id,
        description="A test product for validation",
        base_price=19.99,
        status="active"
    )
    session.add(test_product)
    session.flush()
    
    # Create feature types
    color_type = FeatureType(feature_type="Color", display_order=1, is_required=True)
    size_type = FeatureType(feature_type="Size", display_order=2, is_required=True)
    session.add_all([color_type, size_type])
    session.flush()
    
    # Create some features
    black_color = Feature(
        feature_type_id=color_type.id,
        code="BLK",
        name="Black",
        sort_order=1,
        is_active=True
    )
    
    medium_size = Feature(
        feature_type_id=size_type.id,
        code="M",
        name="Medium",
        sort_order=1,
        is_active=True
    )
    session.add_all([black_color, medium_size])
    session.flush()
    
    # Link features to product
    prod_color = ProductFeature(product_id=test_product.id, feature_id=black_color.id)
    prod_size = ProductFeature(product_id=test_product.id, feature_id=medium_size.id)
    session.add_all([prod_color, prod_size])
    session.flush()
    
    # Create a test SKU
    test_sku = SKU(
        sku="TEST-M-BLK",
        product_id=test_product.id,
        batch_name="Test Batch",
        price=19.99,
        inventory_qty=100,
        status="active"
    )
    session.add(test_sku)
    session.flush()
    
    # Link features to SKU
    sku_color = SKUFeature(sku_id=test_sku.id, feature_id=black_color.id)
    sku_size = SKUFeature(sku_id=test_sku.id, feature_id=medium_size.id)
    session.add_all([sku_color, sku_size])
    
    # Commit all changes
    session.commit()
    
    print("✓ Test data inserted successfully!")
    print(f"\n  Category: {test_category}")
    print(f"  Product: {test_product}")
    print(f"  Feature Types: {color_type}, {size_type}")
    print(f"  Features: {black_color}, {medium_size}")
    print(f"  SKU: {test_sku}")
    print(f"\n  Total records created: 10")
    
except Exception as e:
    session.rollback()
    print(f"✗ Error inserting test data: {e}")
    raise
finally:
    session.close()
# Out:
# 2025-12-02 14:42:01,334 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-02 14:42:01,335 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:42:01,335 INFO sqlalchemy.engine.Engine [generated in 0.00032s] ('Apparel', 'T-Shirts', '2025-12-02 20:42:01.335589', '2025-12-02 20:42:01.335592')
# 2025-12-02 14:42:01,337 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:42:01,337 INFO sqlalchemy.engine.Engine [generated in 0.00046s] ('Test Basic Tee', 1, 'A test product for validation', 19.99, 'active', '2025-12-02 20:42:01.337253', '2025-12-02 20:42:01.337255')
# 2025-12-02 14:42:01,339 INFO sqlalchemy.engine.Engine INSERT INTO feature_types (feature_type, display_order, is_required, created_at) VALUES (?, ?, ?, ?) RETURNING id
# 2025-12-02 14:42:01,339 INFO sqlalchemy.engine.Engine [generated in 0.00007s (insertmanyvalues) 1/2 (ordered; batch not supported)] ('Color', 1, 1, '2025-12-02 20:42:01.339067')
# 2025-12-02 14:42:01,339 INFO sqlalchemy.engine.Engine INSERT INTO feature_types (feature_type, display_order, is_required, created_at) VALUES (?, ?, ?, ?) RETURNING id
# 2025-12-02 14:42:01,339 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/2 (ordered; batch not supported)] ('Size', 2, 1, '2025-12-02 20:42:01.339068')
# 2025-12-02 14:42:01,340 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-12-02 14:42:01,340 INFO sqlalchemy.engine.Engine [generated in 0.00008s (insertmanyvalues) 1/2 (ordered; batch not supported)] (1, 'BLK', 'Black', None, 1, 1, '2025-12-02 20:42:01.340553', '2025-12-02 20:42:01.340555')
# 2025-12-02 14:42:01,341 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-12-02 14:42:01,341 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/2 (ordered; batch not supported)] (2, 'M', 'Medium', None, 1, 1, '2025-12-02 20:42:01.340556', '2025-12-02 20:42:01.340557')
# 2025-12-02 14:42:01,342 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?) RETURNING id
# 2025-12-02 14:42:01,342 INFO sqlalchemy.engine.Engine [generated in 0.00005s (insertmanyvalues) 1/2 (ordered; batch not supported)] (1, 1, '2025-12-02 20:42:01.342361')
# 2025-12-02 14:42:01,342 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?) RETURNING id
# 2025-12-02 14:42:01,342 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/2 (ordered; batch not supported)] (1, 2, '2025-12-02 20:42:01.342363')
# 2025-12-02 14:42:01,343 INFO sqlalchemy.engine.Engine INSERT INTO skus (sku, product_id, batch_name, price, inventory_qty, status, generated_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:42:01,343 INFO sqlalchemy.engine.Engine [generated in 0.00015s] ('TEST-M-BLK', 1, 'Test Batch', 19.99, 100, 'active', '2025-12-02 20:42:01.343573', '2025-12-02 20:42:01.343574')
# 2025-12-02 14:42:01,344 INFO sqlalchemy.engine.Engine INSERT INTO sku_features (sku_id, feature_id, created_at) VALUES (?, ?, ?) RETURNING id
# 2025-12-02 14:42:01,344 INFO sqlalchemy.engine.Engine [generated in 0.00005s (insertmanyvalues) 1/2 (ordered; batch not supported)] (1, 1, '2025-12-02 20:42:01.344562')
# 2025-12-02 14:42:01,345 INFO sqlalchemy.engine.Engine INSERT INTO sku_features (sku_id, feature_id, created_at) VALUES (?, ?, ?) RETURNING id
# 2025-12-02 14:42:01,345 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/2 (ordered; batch not supported)] (1, 2, '2025-12-02 20:42:01.344564')
# 2025-12-02 14:42:01,345 INFO sqlalchemy.engine.Engine COMMIT
# ✓ Test data inserted successfully!
# 2025-12-02 14:42:01,346 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-02 14:42:01,347 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.id = ?
# 2025-12-02 14:42:01,348 INFO sqlalchemy.engine.Engine [generated in 0.00024s] (1,)
#
#   Category: <Category(id=1, category='Apparel', subcategory='T-Shirts')>
# 2025-12-02 14:42:01,349 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.id = ?
# 2025-12-02 14:42:01,349 INFO sqlalchemy.engine.Engine [generated in 0.00014s] (1,)
#   Product: <Product(id=1, name='Test Basic Tee', status='active')>
# 2025-12-02 14:42:01,350 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.id = ?
# 2025-12-02 14:42:01,350 INFO sqlalchemy.engine.Engine [generated in 0.00013s] (1,)
# 2025-12-02 14:42:01,351 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.id = ?
# 2025-12-02 14:42:01,351 INFO sqlalchemy.engine.Engine [cached since 0.0006793s ago] (2,)
#   Feature Types: <FeatureType(id=1, type='Color', required=True)>, <FeatureType(id=2, type='Size', required=True)>
# 2025-12-02 14:42:01,352 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:42:01,352 INFO sqlalchemy.engine.Engine [generated in 0.00016s] (1,)
# 2025-12-02 14:42:01,352 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:42:01,352 INFO sqlalchemy.engine.Engine [cached since 0.0007595s ago] (2,)
#   Features: <Feature(id=1, code='BLK', name='Black')>, <Feature(id=2, code='M', name='Medium')>
# 2025-12-02 14:42:01,353 INFO sqlalchemy.engine.Engine SELECT skus.id AS skus_id, skus.sku AS skus_sku, skus.product_id AS skus_product_id, skus.batch_name AS skus_batch_name, skus.price AS skus_price, skus.inventory_qty AS skus_inventory_qty, skus.status AS skus_status, skus.generated_at AS skus_generated_at, skus.updated_at AS skus_updated_at
# FROM skus
# WHERE skus.id = ?
# 2025-12-02 14:42:01,353 INFO sqlalchemy.engine.Engine [generated in 0.00018s] (1,)
#   SKU: <SKU(id=1, sku='TEST-M-BLK', status='active')>
#
#   Total records created: 10
# 2025-12-02 14:42:01,353 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# ### Step 6: Query Test Data
#
# Verify we can retrieve the data we just inserted.

# %%
# Create a new session for querying
session = Session()

try:
    # Query all SKUs with their related data
    skus = session.query(SKU).all()
    
    print("SKUs in Database:")
    print("=" * 80)
    
    for sku in skus:
        print(f"\nSKU: {sku.sku}")
        print(f"  Product: {sku.product.product_name}")
        print(f"  Category: {sku.product.category.category} → {sku.product.category.subcategory}")
        print(f"  Price: ${sku.price}")
        print(f"  Inventory: {sku.inventory_qty}")
        print(f"  Status: {sku.status}")
        
        # Get features for this SKU
        print(f"  Features:")
        for sku_feature in sku.sku_features:
            feature = sku_feature.feature
            print(f"    - {feature.feature_type.feature_type}: {feature.name} ({feature.code})")
    
    print("\n" + "=" * 80)
    print(f"✓ Query successful! Found {len(skus)} SKU(s)")
    
except Exception as e:
    print(f"✗ Error querying data: {e}")
    raise
finally:
    session.close()
# Out:
# 2025-12-02 14:42:07,428 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-02 14:42:07,429 INFO sqlalchemy.engine.Engine SELECT skus.id AS skus_id, skus.sku AS skus_sku, skus.product_id AS skus_product_id, skus.batch_name AS skus_batch_name, skus.price AS skus_price, skus.inventory_qty AS skus_inventory_qty, skus.status AS skus_status, skus.generated_at AS skus_generated_at, skus.updated_at AS skus_updated_at
# FROM skus
# 2025-12-02 14:42:07,429 INFO sqlalchemy.engine.Engine [generated in 0.00042s] ()
# SKUs in Database:
# ================================================================================
#
# SKU: TEST-M-BLK
# 2025-12-02 14:42:07,432 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.id = ?
# 2025-12-02 14:42:07,432 INFO sqlalchemy.engine.Engine [generated in 0.00041s] (1,)
#   Product: Test Basic Tee
# 2025-12-02 14:42:07,434 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.id = ?
# 2025-12-02 14:42:07,435 INFO sqlalchemy.engine.Engine [generated in 0.00052s] (1,)
#   Category: Apparel → T-Shirts
#   Price: $19.99
#   Inventory: 100
#   Status: active
#   Features:
# 2025-12-02 14:42:07,436 INFO sqlalchemy.engine.Engine SELECT sku_features.id AS sku_features_id, sku_features.sku_id AS sku_features_sku_id, sku_features.feature_id AS sku_features_feature_id, sku_features.created_at AS sku_features_created_at
# FROM sku_features
# WHERE ? = sku_features.sku_id
# 2025-12-02 14:42:07,436 INFO sqlalchemy.engine.Engine [generated in 0.00029s] (1,)
# 2025-12-02 14:42:07,438 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:42:07,438 INFO sqlalchemy.engine.Engine [generated in 0.00044s] (1,)
# 2025-12-02 14:42:07,440 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.id = ?
# 2025-12-02 14:42:07,440 INFO sqlalchemy.engine.Engine [generated in 0.00036s] (1,)
#     - Color: Black (BLK)
# 2025-12-02 14:42:07,441 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:42:07,442 INFO sqlalchemy.engine.Engine [cached since 0.003896s ago] (2,)
# 2025-12-02 14:42:07,442 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.id = ?
# 2025-12-02 14:42:07,442 INFO sqlalchemy.engine.Engine [cached since 0.002422s ago] (2,)
#     - Size: Medium (M)
#
# ================================================================================
# ✓ Query successful! Found 1 SKU(s)
# 2025-12-02 14:42:07,443 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# ## Phase 3: Data Migration from Numbers File
#
# Now let's migrate your existing catalog data from the Numbers file into the database.

# %% [markdown]
# ### Step 1: Load Numbers File
#
# Reuse the data loading function from sku-gen-beta.

# %%
import pandas as pd
from numbers_parser import Document

def load_catalog_data(file_path):
    """Load Apple Numbers file into DataFrames."""
    doc = Document(file_path)
    sheets = doc.sheets
    tables = {}

    for sheet in sheets:
        for table in sheet.tables:
            table_name = table.name.replace(" ", "_")
            data = table.rows(values_only=True)
            tables[table_name] = pd.DataFrame(data[1:], columns=data[0])

    # Clean column names for Product_Catalog
    tables['Product_Catalog'].columns = tables['Product_Catalog'].columns.str.replace(' ', '_')
    
    return tables

# Load the catalog
catalog_file = "../CHARTS/catalog.numbers"
catalog_tables = load_catalog_data(catalog_file)

print("✓ Catalog loaded successfully!")
print(f"  Tables: {list(catalog_tables.keys())}")
print(f"  Products: {len(catalog_tables['Product_Catalog'])}")
print(f"  Feature types: {len(catalog_tables.keys()) - 2}")  # Exclude Product_Catalog and Prefix_Codes
# Out:
# ✓ Catalog loaded successfully!
#   Tables: ['Product_Catalog', 'Size', 'Prefix_Codes', 'Main_Category', 'Sub_Category', 'Fit', 'Color', 'Design', 'Material', 'Scent']
#   Products: 18
#   Feature types: 8

# %% [markdown]
# ### Clean Up Test Data
#
# Remove the test data before migrating real catalog data.

# %%
session = Session()

try:
    # Delete in reverse order of dependencies
    deleted_counts = {}
    
    # SKU Features (depends on SKUs and Features)
    deleted_counts['SKU Features'] = session.query(SKUFeature).delete()
    
    # SKUs (depends on Products)
    deleted_counts['SKUs'] = session.query(SKU).delete()
    
    # Product Features (depends on Products and Features)
    deleted_counts['Product Features'] = session.query(ProductFeature).delete()
    
    # Features (depends on Feature Types)
    deleted_counts['Features'] = session.query(Feature).delete()
    
    # Feature Types (no dependencies)
    deleted_counts['Feature Types'] = session.query(FeatureType).delete()
    
    # Products (depends on Categories)
    deleted_counts['Products'] = session.query(Product).delete()
    
    # Categories (no dependencies)
    deleted_counts['Categories'] = session.query(Category).delete()
    
    session.commit()
    
    print("🧹 Test Data Purged:")
    print("=" * 50)
    for table, count in deleted_counts.items():
        if count > 0:
            print(f"  {table:<20} {count} records deleted")
    print("=" * 50)
    print("✓ Database is now empty and ready for migration!")
    
except Exception as e:
    session.rollback()
    print(f"✗ Error purging test data: {e}")
    raise
finally:
    session.close()
# Out:
# 2025-12-02 14:45:55,335 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-02 14:45:55,336 INFO sqlalchemy.engine.Engine DELETE FROM sku_features
# 2025-12-02 14:45:55,338 INFO sqlalchemy.engine.Engine [generated in 0.00122s] ()
# 2025-12-02 14:45:55,339 INFO sqlalchemy.engine.Engine DELETE FROM skus
# 2025-12-02 14:45:55,339 INFO sqlalchemy.engine.Engine [generated in 0.00037s] ()
# 2025-12-02 14:45:55,340 INFO sqlalchemy.engine.Engine DELETE FROM product_features
# 2025-12-02 14:45:55,341 INFO sqlalchemy.engine.Engine [generated in 0.00040s] ()
# 2025-12-02 14:45:55,341 INFO sqlalchemy.engine.Engine DELETE FROM features
# 2025-12-02 14:45:55,341 INFO sqlalchemy.engine.Engine [generated in 0.00028s] ()
# 2025-12-02 14:45:55,342 INFO sqlalchemy.engine.Engine DELETE FROM feature_types
# 2025-12-02 14:45:55,342 INFO sqlalchemy.engine.Engine [generated in 0.00038s] ()
# 2025-12-02 14:45:55,343 INFO sqlalchemy.engine.Engine DELETE FROM products
# 2025-12-02 14:45:55,343 INFO sqlalchemy.engine.Engine [generated in 0.00021s] ()
# 2025-12-02 14:45:55,344 INFO sqlalchemy.engine.Engine DELETE FROM categories
# 2025-12-02 14:45:55,344 INFO sqlalchemy.engine.Engine [generated in 0.00028s] ()
# 2025-12-02 14:45:55,345 INFO sqlalchemy.engine.Engine COMMIT
# 🧹 Test Data Purged:
# ==================================================
#   SKU Features         2 records deleted
#   SKUs                 1 records deleted
#   Product Features     2 records deleted
#   Features             2 records deleted
#   Feature Types        2 records deleted
#   Products             1 records deleted
#   Categories           1 records deleted
# ==================================================
# ✓ Database is now empty and ready for migration!
# 2025-12-02 14:45:55,336 INFO sqlalchemy.engine.Engine DELETE FROM sku_features
# 2025-12-02 14:45:55,338 INFO sqlalchemy.engine.Engine [generated in 0.00122s] ()
# 2025-12-02 14:45:55,339 INFO sqlalchemy.engine.Engine DELETE FROM skus
# 2025-12-02 14:45:55,339 INFO sqlalchemy.engine.Engine [generated in 0.00037s] ()
# 2025-12-02 14:45:55,340 INFO sqlalchemy.engine.Engine DELETE FROM product_features
# 2025-12-02 14:45:55,341 INFO sqlalchemy.engine.Engine [generated in 0.00040s] ()
# 2025-12-02 14:45:55,341 INFO sqlalchemy.engine.Engine DELETE FROM features
# 2025-12-02 14:45:55,341 INFO sqlalchemy.engine.Engine [generated in 0.00028s] ()
# 2025-12-02 14:45:55,342 INFO sqlalchemy.engine.Engine DELETE FROM feature_types
# 2025-12-02 14:45:55,342 INFO sqlalchemy.engine.Engine [generated in 0.00038s] ()
# 2025-12-02 14:45:55,343 INFO sqlalchemy.engine.Engine DELETE FROM products
# 2025-12-02 14:45:55,343 INFO sqlalchemy.engine.Engine [generated in 0.00021s] ()
# 2025-12-02 14:45:55,344 INFO sqlalchemy.engine.Engine DELETE FROM categories
# 2025-12-02 14:45:55,344 INFO sqlalchemy.engine.Engine [generated in 0.00028s] ()
# 2025-12-02 14:45:55,345 INFO sqlalchemy.engine.Engine COMMIT
# 🧹 Test Data Purged:
# ==================================================
#   SKU Features         2 records deleted
#   SKUs                 1 records deleted
#   Product Features     2 records deleted
#   Features             2 records deleted
#   Feature Types        2 records deleted
#   Products             1 records deleted
#   Categories           1 records deleted
# ==================================================
# ✓ Database is now empty and ready for migration!

# %% [markdown]
# ### Step 2: Migrate Categories
#
# Extract unique categories and subcategories from the catalog.

# %%
session = Session()

try:
    # Get unique category combinations from Product_Catalog
    category_combos = catalog_tables['Product_Catalog'][['Main_Category', 'Sub_Category']].drop_duplicates()
    
    print(f"Found {len(category_combos)} unique category combinations:")
    
    for _, row in category_combos.iterrows():
        # Check if category already exists
        existing = session.query(Category).filter_by(
            category=row['Main_Category'],
            subcategory=row['Sub_Category']
        ).first()
        
        if not existing:
            category = Category(
                category=row['Main_Category'],
                subcategory=row['Sub_Category']
            )
            session.add(category)
            print(f"  + {row['Main_Category']} → {row['Sub_Category']}")
        else:
            print(f"  - {row['Main_Category']} → {row['Sub_Category']} (already exists)")
    
    session.commit()
    print("\n✓ Categories migrated successfully!")
    
except Exception as e:
    session.rollback()
    print(f"✗ Error migrating categories: {e}")
    raise
finally:
    session.close()
# Out:
# Found 11 unique category combinations:
# 2025-12-02 14:46:39,902 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-02 14:46:39,903 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,903 INFO sqlalchemy.engine.Engine [generated in 0.00051s] ('Shirt', 'Tee Shirt', 1, 0)
#   + Shirt → Tee Shirt
# 2025-12-02 14:46:39,905 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,905 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Shirt', 'Tee Shirt', '2025-12-02 20:46:39.905319', '2025-12-02 20:46:39.905323')
# 2025-12-02 14:46:39,906 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,906 INFO sqlalchemy.engine.Engine [cached since 0.003525s ago] ('Shirt', 'Long Sleeve Tee Shirt', 1, 0)
#   + Shirt → Long Sleeve Tee Shirt
# 2025-12-02 14:46:39,907 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,907 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Shirt', 'Long Sleeve Tee Shirt', '2025-12-02 20:46:39.907653', '2025-12-02 20:46:39.907656')
# 2025-12-02 14:46:39,908 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,908 INFO sqlalchemy.engine.Engine [cached since 0.005469s ago] ('Shirt', 'Polo', 1, 0)
#   + Shirt → Polo
# 2025-12-02 14:46:39,909 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,909 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Shirt', 'Polo', '2025-12-02 20:46:39.909390', '2025-12-02 20:46:39.909392')
# 2025-12-02 14:46:39,910 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,910 INFO sqlalchemy.engine.Engine [cached since 0.007005s ago] ('Outerwear', 'Sweater', 1, 0)
#   + Outerwear → Sweater
# 2025-12-02 14:46:39,910 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,911 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Outerwear', 'Sweater', '2025-12-02 20:46:39.910853', '2025-12-02 20:46:39.910856')
# 2025-12-02 14:46:39,911 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,911 INFO sqlalchemy.engine.Engine [cached since 0.008387s ago] ('Outerwear', 'Hoody', 1, 0)
#   + Outerwear → Hoody
# 2025-12-02 14:46:39,912 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,903 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,903 INFO sqlalchemy.engine.Engine [generated in 0.00051s] ('Shirt', 'Tee Shirt', 1, 0)
#   + Shirt → Tee Shirt
# 2025-12-02 14:46:39,905 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,905 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Shirt', 'Tee Shirt', '2025-12-02 20:46:39.905319', '2025-12-02 20:46:39.905323')
# 2025-12-02 14:46:39,906 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,906 INFO sqlalchemy.engine.Engine [cached since 0.003525s ago] ('Shirt', 'Long Sleeve Tee Shirt', 1, 0)
#   + Shirt → Long Sleeve Tee Shirt
# 2025-12-02 14:46:39,907 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,907 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Shirt', 'Long Sleeve Tee Shirt', '2025-12-02 20:46:39.907653', '2025-12-02 20:46:39.907656')
# 2025-12-02 14:46:39,908 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,908 INFO sqlalchemy.engine.Engine [cached since 0.005469s ago] ('Shirt', 'Polo', 1, 0)
#   + Shirt → Polo
# 2025-12-02 14:46:39,909 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,909 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Shirt', 'Polo', '2025-12-02 20:46:39.909390', '2025-12-02 20:46:39.909392')
# 2025-12-02 14:46:39,910 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,910 INFO sqlalchemy.engine.Engine [cached since 0.007005s ago] ('Outerwear', 'Sweater', 1, 0)
#   + Outerwear → Sweater
# 2025-12-02 14:46:39,910 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,911 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Outerwear', 'Sweater', '2025-12-02 20:46:39.910853', '2025-12-02 20:46:39.910856')
# 2025-12-02 14:46:39,911 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,911 INFO sqlalchemy.engine.Engine [cached since 0.008387s ago] ('Outerwear', 'Hoody', 1, 0)
#   + Outerwear → Hoody
# 2025-12-02 14:46:39,912 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,912 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Outerwear', 'Hoody', '2025-12-02 20:46:39.912193', '2025-12-02 20:46:39.912194')
# 2025-12-02 14:46:39,912 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,912 INFO sqlalchemy.engine.Engine [cached since 0.009633s ago] ('Outerwear', 'Jacket', 1, 0)
#   + Outerwear → Jacket
# 2025-12-02 14:46:39,913 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,913 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Outerwear', 'Jacket', '2025-12-02 20:46:39.913601', '2025-12-02 20:46:39.913604')
# 2025-12-02 14:46:39,914 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,914 INFO sqlalchemy.engine.Engine [cached since 0.01118s ago] ('Headwear', 'Trucker Hat', 1, 0)
#   + Headwear → Trucker Hat
# 2025-12-02 14:46:39,915 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,915 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Headwear', 'Trucker Hat', '2025-12-02 20:46:39.915045', '2025-12-02 20:46:39.915050')
# 2025-12-02 14:46:39,915 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,916 INFO sqlalchemy.engine.Engine [cached since 0.01279s ago] ('Headwear', 'Ball Cap', 1, 0)
#   + Headwear → Ball Cap
# 2025-12-02 14:46:39,916 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,916 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Headwear', 'Ball Cap', '2025-12-02 20:46:39.916667', '2025-12-02 20:46:39.916670')
# 2025-12-02 14:46:39,917 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,917 INFO sqlalchemy.engine.Engine [cached since 0.01426s ago] ('Headwear', 'Flex Fit Hat', 1, 0)
#   + Headwear → Flex Fit Hat
# 2025-12-02 14:46:39,918 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,918 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Headwear', 'Flex Fit Hat', '2025-12-02 20:46:39.918161', '2025-12-02 20:46:39.918163')
# 2025-12-02 14:46:39,912 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Outerwear', 'Hoody', '2025-12-02 20:46:39.912193', '2025-12-02 20:46:39.912194')
# 2025-12-02 14:46:39,912 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,912 INFO sqlalchemy.engine.Engine [cached since 0.009633s ago] ('Outerwear', 'Jacket', 1, 0)
#   + Outerwear → Jacket
# 2025-12-02 14:46:39,913 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,913 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Outerwear', 'Jacket', '2025-12-02 20:46:39.913601', '2025-12-02 20:46:39.913604')
# 2025-12-02 14:46:39,914 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,914 INFO sqlalchemy.engine.Engine [cached since 0.01118s ago] ('Headwear', 'Trucker Hat', 1, 0)
#   + Headwear → Trucker Hat
# 2025-12-02 14:46:39,915 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,915 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Headwear', 'Trucker Hat', '2025-12-02 20:46:39.915045', '2025-12-02 20:46:39.915050')
# 2025-12-02 14:46:39,915 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,916 INFO sqlalchemy.engine.Engine [cached since 0.01279s ago] ('Headwear', 'Ball Cap', 1, 0)
#   + Headwear → Ball Cap
# 2025-12-02 14:46:39,916 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,916 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Headwear', 'Ball Cap', '2025-12-02 20:46:39.916667', '2025-12-02 20:46:39.916670')
# 2025-12-02 14:46:39,917 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,917 INFO sqlalchemy.engine.Engine [cached since 0.01426s ago] ('Headwear', 'Flex Fit Hat', 1, 0)
#   + Headwear → Flex Fit Hat
# 2025-12-02 14:46:39,918 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,918 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Headwear', 'Flex Fit Hat', '2025-12-02 20:46:39.918161', '2025-12-02 20:46:39.918163')
# 2025-12-02 14:46:39,919 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,919 INFO sqlalchemy.engine.Engine [cached since 0.01608s ago] ('Accessories', 'Air Freshener', 1, 0)
#   + Accessories → Air Freshener
# 2025-12-02 14:46:39,920 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,920 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Accessories', 'Air Freshener', '2025-12-02 20:46:39.920014', '2025-12-02 20:46:39.920016')
# 2025-12-02 14:46:39,920 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,920 INFO sqlalchemy.engine.Engine [cached since 0.01753s ago] ('Accessories', 'Keychain', 1, 0)
#   + Accessories → Keychain
# 2025-12-02 14:46:39,921 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,921 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Accessories', 'Keychain', '2025-12-02 20:46:39.921191', '2025-12-02 20:46:39.921193')
# 2025-12-02 14:46:39,921 INFO sqlalchemy.engine.Engine COMMIT
#
# ✓ Categories migrated successfully!
# 2025-12-02 14:46:39,919 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,919 INFO sqlalchemy.engine.Engine [cached since 0.01608s ago] ('Accessories', 'Air Freshener', 1, 0)
#   + Accessories → Air Freshener
# 2025-12-02 14:46:39,920 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,920 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Accessories', 'Air Freshener', '2025-12-02 20:46:39.920014', '2025-12-02 20:46:39.920016')
# 2025-12-02 14:46:39,920 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:46:39,920 INFO sqlalchemy.engine.Engine [cached since 0.01753s ago] ('Accessories', 'Keychain', 1, 0)
#   + Accessories → Keychain
# 2025-12-02 14:46:39,921 INFO sqlalchemy.engine.Engine INSERT INTO categories (category, subcategory, created_at, updated_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:46:39,921 INFO sqlalchemy.engine.Engine [cached since 278.6s ago] ('Accessories', 'Keychain', '2025-12-02 20:46:39.921191', '2025-12-02 20:46:39.921193')
# 2025-12-02 14:46:39,921 INFO sqlalchemy.engine.Engine COMMIT
#
# ✓ Categories migrated successfully!

# %% [markdown]
# ### Step 3: Migrate Feature Types
#
# Create feature types from the code sheet names.

# %%
session = Session()

try:
    # Get feature sheet names (exclude Product_Catalog, Prefix_Codes, Main_Category, Sub_Category)
    exclude_sheets = ['Product_Catalog', 'Prefix_Codes', 'Main_Category', 'Sub_Category']
    feature_sheets = [name for name in catalog_tables.keys() if name not in exclude_sheets]
    
    print(f"Creating {len(feature_sheets)} feature types:")
    
    for idx, feature_name in enumerate(feature_sheets):
        existing = session.query(FeatureType).filter_by(feature_type=feature_name).first()
        
        if not existing:
            feature_type = FeatureType(
                feature_type=feature_name,
                display_order=idx + 1,
                is_required=True  # You can adjust this per feature type
            )
            session.add(feature_type)
            print(f"  + {feature_name} (order: {idx + 1})")
        else:
            print(f"  - {feature_name} (already exists)")
    
    session.commit()
    print("\n✓ Feature types migrated successfully!")
    
except Exception as e:
    session.rollback()
    print(f"✗ Error migrating feature types: {e}")
    raise
finally:
    session.close()
# Out:
# Creating 6 feature types:
# 2025-12-02 14:47:49,825 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-02 14:47:49,827 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:49,827 INFO sqlalchemy.engine.Engine [generated in 0.00064s] ('Size', 1, 0)
#   + Size (order: 1)
# 2025-12-02 14:47:49,829 INFO sqlalchemy.engine.Engine INSERT INTO feature_types (feature_type, display_order, is_required, created_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:47:49,829 INFO sqlalchemy.engine.Engine [generated in 0.00038s] ('Size', 1, 1, '2025-12-02 20:47:49.829032')
# 2025-12-02 14:47:49,830 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:49,830 INFO sqlalchemy.engine.Engine [cached since 0.003703s ago] ('Fit', 1, 0)
#   + Fit (order: 2)
# 2025-12-02 14:47:49,831 INFO sqlalchemy.engine.Engine INSERT INTO feature_types (feature_type, display_order, is_required, created_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:47:49,831 INFO sqlalchemy.engine.Engine [cached since 0.002851s ago] ('Fit', 2, 1, '2025-12-02 20:47:49.831351')
# 2025-12-02 14:47:49,832 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:49,832 INFO sqlalchemy.engine.Engine [cached since 0.005929s ago] ('Color', 1, 0)
#   + Color (order: 3)
# 2025-12-02 14:47:49,833 INFO sqlalchemy.engine.Engine INSERT INTO feature_types (feature_type, display_order, is_required, created_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:47:49,833 INFO sqlalchemy.engine.Engine [cached since 0.004923s ago] ('Color', 3, 1, '2025-12-02 20:47:49.833625')
# 2025-12-02 14:47:49,834 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:49,834 INFO sqlalchemy.engine.Engine [cached since 0.007857s ago] ('Design', 1, 0)
#   + Design (order: 4)
# 2025-12-02 14:47:49,835 INFO sqlalchemy.engine.Engine INSERT INTO feature_types (feature_type, display_order, is_required, created_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:47:49,827 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:49,827 INFO sqlalchemy.engine.Engine [generated in 0.00064s] ('Size', 1, 0)
#   + Size (order: 1)
# 2025-12-02 14:47:49,829 INFO sqlalchemy.engine.Engine INSERT INTO feature_types (feature_type, display_order, is_required, created_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:47:49,829 INFO sqlalchemy.engine.Engine [generated in 0.00038s] ('Size', 1, 1, '2025-12-02 20:47:49.829032')
# 2025-12-02 14:47:49,830 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:49,830 INFO sqlalchemy.engine.Engine [cached since 0.003703s ago] ('Fit', 1, 0)
#   + Fit (order: 2)
# 2025-12-02 14:47:49,831 INFO sqlalchemy.engine.Engine INSERT INTO feature_types (feature_type, display_order, is_required, created_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:47:49,831 INFO sqlalchemy.engine.Engine [cached since 0.002851s ago] ('Fit', 2, 1, '2025-12-02 20:47:49.831351')
# 2025-12-02 14:47:49,832 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:49,832 INFO sqlalchemy.engine.Engine [cached since 0.005929s ago] ('Color', 1, 0)
#   + Color (order: 3)
# 2025-12-02 14:47:49,833 INFO sqlalchemy.engine.Engine INSERT INTO feature_types (feature_type, display_order, is_required, created_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:47:49,833 INFO sqlalchemy.engine.Engine [cached since 0.004923s ago] ('Color', 3, 1, '2025-12-02 20:47:49.833625')
# 2025-12-02 14:47:49,834 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:49,834 INFO sqlalchemy.engine.Engine [cached since 0.007857s ago] ('Design', 1, 0)
#   + Design (order: 4)
# 2025-12-02 14:47:49,835 INFO sqlalchemy.engine.Engine INSERT INTO feature_types (feature_type, display_order, is_required, created_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:47:49,835 INFO sqlalchemy.engine.Engine [cached since 0.006791s ago] ('Design', 4, 1, '2025-12-02 20:47:49.835500')
# 2025-12-02 14:47:49,836 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:49,836 INFO sqlalchemy.engine.Engine [cached since 0.009747s ago] ('Material', 1, 0)
#   + Material (order: 5)
# 2025-12-02 14:47:49,837 INFO sqlalchemy.engine.Engine INSERT INTO feature_types (feature_type, display_order, is_required, created_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:47:49,837 INFO sqlalchemy.engine.Engine [cached since 0.008491s ago] ('Material', 5, 1, '2025-12-02 20:47:49.837250')
# 2025-12-02 14:47:49,838 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:49,838 INFO sqlalchemy.engine.Engine [cached since 0.01142s ago] ('Scent', 1, 0)
#   + Scent (order: 6)
# 2025-12-02 14:47:49,838 INFO sqlalchemy.engine.Engine INSERT INTO feature_types (feature_type, display_order, is_required, created_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:47:49,839 INFO sqlalchemy.engine.Engine [cached since 0.01001s ago] ('Scent', 6, 1, '2025-12-02 20:47:49.838785')
# 2025-12-02 14:47:49,839 INFO sqlalchemy.engine.Engine COMMIT
#
# ✓ Feature types migrated successfully!
# 2025-12-02 14:47:49,835 INFO sqlalchemy.engine.Engine [cached since 0.006791s ago] ('Design', 4, 1, '2025-12-02 20:47:49.835500')
# 2025-12-02 14:47:49,836 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:49,836 INFO sqlalchemy.engine.Engine [cached since 0.009747s ago] ('Material', 1, 0)
#   + Material (order: 5)
# 2025-12-02 14:47:49,837 INFO sqlalchemy.engine.Engine INSERT INTO feature_types (feature_type, display_order, is_required, created_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:47:49,837 INFO sqlalchemy.engine.Engine [cached since 0.008491s ago] ('Material', 5, 1, '2025-12-02 20:47:49.837250')
# 2025-12-02 14:47:49,838 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:49,838 INFO sqlalchemy.engine.Engine [cached since 0.01142s ago] ('Scent', 1, 0)
#   + Scent (order: 6)
# 2025-12-02 14:47:49,838 INFO sqlalchemy.engine.Engine INSERT INTO feature_types (feature_type, display_order, is_required, created_at) VALUES (?, ?, ?, ?)
# 2025-12-02 14:47:49,839 INFO sqlalchemy.engine.Engine [cached since 0.01001s ago] ('Scent', 6, 1, '2025-12-02 20:47:49.838785')
# 2025-12-02 14:47:49,839 INFO sqlalchemy.engine.Engine COMMIT
#
# ✓ Feature types migrated successfully!

# %% [markdown]
# ### Step 4: Migrate Features
#
# Load all feature values from the code sheets.

# %%
session = Session()

try:
    exclude_sheets = ['Product_Catalog', 'Prefix_Codes', 'Main_Category', 'Sub_Category']
    feature_sheets = [name for name in catalog_tables.keys() if name not in exclude_sheets]
    
    total_features = 0
    
    for feature_type_name in feature_sheets:
        # Get the feature type from DB
        feature_type = session.query(FeatureType).filter_by(feature_type=feature_type_name).first()
        
        if not feature_type:
            print(f"✗ Feature type '{feature_type_name}' not found, skipping...")
            continue
        
        # Get the feature data from Numbers
        feature_df = catalog_tables[feature_type_name]
        
        print(f"\n{feature_type_name}:")
        
        for idx, row in feature_df.iterrows():
            # Check if feature already exists
            existing = session.query(Feature).filter_by(
                feature_type_id=feature_type.id,
                code=row['Prefix']
            ).first()
            
            if not existing:
                feature = Feature(
                    feature_type_id=feature_type.id,
                    code=row['Prefix'],
                    name=row['Name'],
                    description=row.get('Comments', None),
                    sort_order=int(idx),
                    is_active=True
                )
                session.add(feature)
                total_features += 1
                print(f"  + {row['Prefix']}: {row['Name']}")
            else:
                print(f"  - {row['Prefix']}: {row['Name']} (already exists)")
    
    session.commit()
    print(f"\n✓ {total_features} features migrated successfully!")
    
except Exception as e:
    session.rollback()
    print(f"✗ Error migrating features: {e}")
    raise
finally:
    session.close()
# Out:
# 2025-12-02 14:47:52,786 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-02 14:47:52,787 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,787 INFO sqlalchemy.engine.Engine [cached since 2.961s ago] ('Size', 1, 0)
#
# Size:
# 2025-12-02 14:47:52,790 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,790 INFO sqlalchemy.engine.Engine [generated in 0.00052s] (1, 'SNAN', 1, 0)
#   + SNAN: Not Applicable
# 2025-12-02 14:47:52,791 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,792 INFO sqlalchemy.engine.Engine [generated in 0.00029s] (1, 'SNAN', 'Not Applicable', 'Non Apparel Items', 0, 1, '2025-12-02 20:47:52.791769', '2025-12-02 20:47:52.791772')
# 2025-12-02 14:47:52,792 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,793 INFO sqlalchemy.engine.Engine [cached since 0.003166s ago] (1, 'CS', 1, 0)
#   + CS: Child Small
# 2025-12-02 14:47:52,794 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,794 INFO sqlalchemy.engine.Engine [cached since 0.002655s ago] (1, 'CS', 'Child Small', None, 1, 1, '2025-12-02 20:47:52.794021', '2025-12-02 20:47:52.794023')
# 2025-12-02 14:47:52,795 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,795 INFO sqlalchemy.engine.Engine [cached since 0.005339s ago] (1, 'CM', 1, 0)
#   + CM: Child Medium
# 2025-12-02 14:47:52,796 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,787 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,787 INFO sqlalchemy.engine.Engine [cached since 2.961s ago] ('Size', 1, 0)
#
# Size:
# 2025-12-02 14:47:52,790 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,790 INFO sqlalchemy.engine.Engine [generated in 0.00052s] (1, 'SNAN', 1, 0)
#   + SNAN: Not Applicable
# 2025-12-02 14:47:52,791 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,792 INFO sqlalchemy.engine.Engine [generated in 0.00029s] (1, 'SNAN', 'Not Applicable', 'Non Apparel Items', 0, 1, '2025-12-02 20:47:52.791769', '2025-12-02 20:47:52.791772')
# 2025-12-02 14:47:52,792 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,793 INFO sqlalchemy.engine.Engine [cached since 0.003166s ago] (1, 'CS', 1, 0)
#   + CS: Child Small
# 2025-12-02 14:47:52,794 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,794 INFO sqlalchemy.engine.Engine [cached since 0.002655s ago] (1, 'CS', 'Child Small', None, 1, 1, '2025-12-02 20:47:52.794021', '2025-12-02 20:47:52.794023')
# 2025-12-02 14:47:52,795 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,795 INFO sqlalchemy.engine.Engine [cached since 0.005339s ago] (1, 'CM', 1, 0)
#   + CM: Child Medium
# 2025-12-02 14:47:52,796 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,796 INFO sqlalchemy.engine.Engine [cached since 0.004901s ago] (1, 'CM', 'Child Medium', None, 2, 1, '2025-12-02 20:47:52.796318', '2025-12-02 20:47:52.796321')
# 2025-12-02 14:47:52,797 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,797 INFO sqlalchemy.engine.Engine [cached since 0.007462s ago] (1, 'CL', 1, 0)
#   + CL: Child Large
# 2025-12-02 14:47:52,798 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,798 INFO sqlalchemy.engine.Engine [cached since 0.006675s ago] (1, 'CL', 'Child Large', None, 3, 1, '2025-12-02 20:47:52.798168', '2025-12-02 20:47:52.798170')
# 2025-12-02 14:47:52,798 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,799 INFO sqlalchemy.engine.Engine [cached since 0.00909s ago] (1, 'XS', 1, 0)
#   + XS: Extra Small
# 2025-12-02 14:47:52,799 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,800 INFO sqlalchemy.engine.Engine [cached since 0.008293s ago] (1, 'XS', 'Extra Small', None, 4, 1, '2025-12-02 20:47:52.799823', '2025-12-02 20:47:52.799825')
# 2025-12-02 14:47:52,800 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,800 INFO sqlalchemy.engine.Engine [cached since 0.01067s ago] (1, 'S', 1, 0)
#   + S: Small
# 2025-12-02 14:47:52,801 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,801 INFO sqlalchemy.engine.Engine [cached since 0.00983s ago] (1, 'S', 'Small', None, 5, 1, '2025-12-02 20:47:52.801303', '2025-12-02 20:47:52.801305')
# 2025-12-02 14:47:52,801 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,802 INFO sqlalchemy.engine.Engine [cached since 0.01209s ago] (1, 'M', 1, 0)
#   + M: Medium
# 2025-12-02 14:47:52,803 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,803 INFO sqlalchemy.engine.Engine [cached since 0.01201s ago] (1, 'M', 'Medium', None, 6, 1, '2025-12-02 20:47:52.803147', '2025-12-02 20:47:52.803150')
# 2025-12-02 14:47:52,804 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,804 INFO sqlalchemy.engine.Engine [cached since 0.01467s ago] (1, 'L', 1, 0)
#   + L: Large
# 2025-12-02 14:47:52,805 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,805 INFO sqlalchemy.engine.Engine [cached since 0.01388s ago] (1, 'L', 'Large', None, 7, 1, '2025-12-02 20:47:52.805357', '2025-12-02 20:47:52.805359')
# 2025-12-02 14:47:52,806 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,806 INFO sqlalchemy.engine.Engine [cached since 0.01631s ago] (1, 'XL', 1, 0)
# 2025-12-02 14:47:52,796 INFO sqlalchemy.engine.Engine [cached since 0.004901s ago] (1, 'CM', 'Child Medium', None, 2, 1, '2025-12-02 20:47:52.796318', '2025-12-02 20:47:52.796321')
# 2025-12-02 14:47:52,797 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,797 INFO sqlalchemy.engine.Engine [cached since 0.007462s ago] (1, 'CL', 1, 0)
#   + CL: Child Large
# 2025-12-02 14:47:52,798 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,798 INFO sqlalchemy.engine.Engine [cached since 0.006675s ago] (1, 'CL', 'Child Large', None, 3, 1, '2025-12-02 20:47:52.798168', '2025-12-02 20:47:52.798170')
# 2025-12-02 14:47:52,798 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,799 INFO sqlalchemy.engine.Engine [cached since 0.00909s ago] (1, 'XS', 1, 0)
#   + XS: Extra Small
# 2025-12-02 14:47:52,799 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,800 INFO sqlalchemy.engine.Engine [cached since 0.008293s ago] (1, 'XS', 'Extra Small', None, 4, 1, '2025-12-02 20:47:52.799823', '2025-12-02 20:47:52.799825')
# 2025-12-02 14:47:52,800 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,800 INFO sqlalchemy.engine.Engine [cached since 0.01067s ago] (1, 'S', 1, 0)
#   + S: Small
# 2025-12-02 14:47:52,801 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,801 INFO sqlalchemy.engine.Engine [cached since 0.00983s ago] (1, 'S', 'Small', None, 5, 1, '2025-12-02 20:47:52.801303', '2025-12-02 20:47:52.801305')
# 2025-12-02 14:47:52,801 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,802 INFO sqlalchemy.engine.Engine [cached since 0.01209s ago] (1, 'M', 1, 0)
#   + M: Medium
# 2025-12-02 14:47:52,803 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,803 INFO sqlalchemy.engine.Engine [cached since 0.01201s ago] (1, 'M', 'Medium', None, 6, 1, '2025-12-02 20:47:52.803147', '2025-12-02 20:47:52.803150')
# 2025-12-02 14:47:52,804 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,804 INFO sqlalchemy.engine.Engine [cached since 0.01467s ago] (1, 'L', 1, 0)
#   + L: Large
# 2025-12-02 14:47:52,805 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,805 INFO sqlalchemy.engine.Engine [cached since 0.01388s ago] (1, 'L', 'Large', None, 7, 1, '2025-12-02 20:47:52.805357', '2025-12-02 20:47:52.805359')
# 2025-12-02 14:47:52,806 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,806 INFO sqlalchemy.engine.Engine [cached since 0.01631s ago] (1, 'XL', 1, 0)
#   + XL: Extra Large
# 2025-12-02 14:47:52,806 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,807 INFO sqlalchemy.engine.Engine [cached since 0.01545s ago] (1, 'XL', 'Extra Large', None, 8, 1, '2025-12-02 20:47:52.806933', '2025-12-02 20:47:52.806935')
# 2025-12-02 14:47:52,807 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,807 INFO sqlalchemy.engine.Engine [cached since 0.01775s ago] (1, '2XL', 1, 0)
#   + 2XL: Double Extra Large
# 2025-12-02 14:47:52,808 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,808 INFO sqlalchemy.engine.Engine [cached since 0.01679s ago] (1, '2XL', 'Double Extra Large', None, 9, 1, '2025-12-02 20:47:52.808344', '2025-12-02 20:47:52.808346')
# 2025-12-02 14:47:52,808 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,809 INFO sqlalchemy.engine.Engine [cached since 0.01924s ago] (1, '3XL', 1, 0)
#   + 3XL: Triple Extra Large
# 2025-12-02 14:47:52,809 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,809 INFO sqlalchemy.engine.Engine [cached since 0.01826s ago] (1, '3XL', 'Triple Extra Large', None, 10, 1, '2025-12-02 20:47:52.809823', '2025-12-02 20:47:52.809828')
# 2025-12-02 14:47:52,810 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,810 INFO sqlalchemy.engine.Engine [cached since 0.0205s ago] (1, '4XL', 1, 0)
#   + 4XL: Quadruple Extra Large
# 2025-12-02 14:47:52,811 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,811 INFO sqlalchemy.engine.Engine [cached since 0.0195s ago] (1, '4XL', 'Quadruple Extra Large', None, 11, 1, '2025-12-02 20:47:52.811024', '2025-12-02 20:47:52.811026')
# 2025-12-02 14:47:52,811 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,811 INFO sqlalchemy.engine.Engine [cached since 0.02168s ago] (1, '5XL', 1, 0)
#   + 5XL: Quintuple Extra Large
# 2025-12-02 14:47:52,812 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,812 INFO sqlalchemy.engine.Engine [cached since 0.02076s ago] (1, '5XL', 'Quintuple Extra Large', None, 12, 1, '2025-12-02 20:47:52.812220', '2025-12-02 20:47:52.812222')
# 2025-12-02 14:47:52,812 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,813 INFO sqlalchemy.engine.Engine [cached since 0.02324s ago] (1, 'S/M', 1, 0)
#   + S/M: Small to Medium
# 2025-12-02 14:47:52,813 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,814 INFO sqlalchemy.engine.Engine [cached since 0.02229s ago] (1, 'S/M', 'Small to Medium', 'Hats Only', 13, 1, '2025-12-02 20:47:52.813826', '2025-12-02 20:47:52.813828')
# 2025-12-02 14:47:52,814 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,814 INFO sqlalchemy.engine.Engine [cached since 0.0245s ago] (1, 'L/XL', 1, 0)
#   + L/XL: Large to Extra Large
# 2025-12-02 14:47:52,815 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,815 INFO sqlalchemy.engine.Engine [cached since 0.02348s ago] (1, 'L/XL', 'Large to Extra Large', 'Hats Only', 14, 1, '2025-12-02 20:47:52.815003', '2025-12-02 20:47:52.815004')
# 2025-12-02 14:47:52,815 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,815 INFO sqlalchemy.engine.Engine [cached since 2.989s ago] ('Fit', 1, 0)
#
# Fit:
# 2025-12-02 14:47:52,816 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,816 INFO sqlalchemy.engine.Engine [cached since 0.02634s ago] (2, 'FTNAN', 1, 0)
#   + FTNAN: Not Applicable
# 2025-12-02 14:47:52,816 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
#   + XL: Extra Large
# 2025-12-02 14:47:52,806 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,807 INFO sqlalchemy.engine.Engine [cached since 0.01545s ago] (1, 'XL', 'Extra Large', None, 8, 1, '2025-12-02 20:47:52.806933', '2025-12-02 20:47:52.806935')
# 2025-12-02 14:47:52,807 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,807 INFO sqlalchemy.engine.Engine [cached since 0.01775s ago] (1, '2XL', 1, 0)
#   + 2XL: Double Extra Large
# 2025-12-02 14:47:52,808 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,808 INFO sqlalchemy.engine.Engine [cached since 0.01679s ago] (1, '2XL', 'Double Extra Large', None, 9, 1, '2025-12-02 20:47:52.808344', '2025-12-02 20:47:52.808346')
# 2025-12-02 14:47:52,808 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,809 INFO sqlalchemy.engine.Engine [cached since 0.01924s ago] (1, '3XL', 1, 0)
#   + 3XL: Triple Extra Large
# 2025-12-02 14:47:52,809 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,809 INFO sqlalchemy.engine.Engine [cached since 0.01826s ago] (1, '3XL', 'Triple Extra Large', None, 10, 1, '2025-12-02 20:47:52.809823', '2025-12-02 20:47:52.809828')
# 2025-12-02 14:47:52,810 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,810 INFO sqlalchemy.engine.Engine [cached since 0.0205s ago] (1, '4XL', 1, 0)
#   + 4XL: Quadruple Extra Large
# 2025-12-02 14:47:52,811 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,811 INFO sqlalchemy.engine.Engine [cached since 0.0195s ago] (1, '4XL', 'Quadruple Extra Large', None, 11, 1, '2025-12-02 20:47:52.811024', '2025-12-02 20:47:52.811026')
# 2025-12-02 14:47:52,811 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,811 INFO sqlalchemy.engine.Engine [cached since 0.02168s ago] (1, '5XL', 1, 0)
#   + 5XL: Quintuple Extra Large
# 2025-12-02 14:47:52,812 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,812 INFO sqlalchemy.engine.Engine [cached since 0.02076s ago] (1, '5XL', 'Quintuple Extra Large', None, 12, 1, '2025-12-02 20:47:52.812220', '2025-12-02 20:47:52.812222')
# 2025-12-02 14:47:52,812 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,813 INFO sqlalchemy.engine.Engine [cached since 0.02324s ago] (1, 'S/M', 1, 0)
#   + S/M: Small to Medium
# 2025-12-02 14:47:52,813 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,814 INFO sqlalchemy.engine.Engine [cached since 0.02229s ago] (1, 'S/M', 'Small to Medium', 'Hats Only', 13, 1, '2025-12-02 20:47:52.813826', '2025-12-02 20:47:52.813828')
# 2025-12-02 14:47:52,814 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,814 INFO sqlalchemy.engine.Engine [cached since 0.0245s ago] (1, 'L/XL', 1, 0)
#   + L/XL: Large to Extra Large
# 2025-12-02 14:47:52,815 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,815 INFO sqlalchemy.engine.Engine [cached since 0.02348s ago] (1, 'L/XL', 'Large to Extra Large', 'Hats Only', 14, 1, '2025-12-02 20:47:52.815003', '2025-12-02 20:47:52.815004')
# 2025-12-02 14:47:52,815 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,815 INFO sqlalchemy.engine.Engine [cached since 2.989s ago] ('Fit', 1, 0)
#
# Fit:
# 2025-12-02 14:47:52,816 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,816 INFO sqlalchemy.engine.Engine [cached since 0.02634s ago] (2, 'FTNAN', 1, 0)
#   + FTNAN: Not Applicable
# 2025-12-02 14:47:52,816 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,816 INFO sqlalchemy.engine.Engine [cached since 0.02519s ago] (2, 'FTNAN', 'Not Applicable', None, 0, 1, '2025-12-02 20:47:52.816755', '2025-12-02 20:47:52.816757')
# 2025-12-02 14:47:52,817 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,817 INFO sqlalchemy.engine.Engine [cached since 0.02733s ago] (2, 'USX', 1, 0)
#   + USX: Unisex
# 2025-12-02 14:47:52,817 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,817 INFO sqlalchemy.engine.Engine [cached since 0.02616s ago] (2, 'USX', 'Unisex', None, 1, 1, '2025-12-02 20:47:52.817728', '2025-12-02 20:47:52.817730')
# 2025-12-02 14:47:52,818 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,818 INFO sqlalchemy.engine.Engine [cached since 0.0284s ago] (2, 'MLE', 1, 0)
#   + MLE: Male
# 2025-12-02 14:47:52,819 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,819 INFO sqlalchemy.engine.Engine [cached since 0.02747s ago] (2, 'MLE', 'Male', None, 2, 1, '2025-12-02 20:47:52.818980', '2025-12-02 20:47:52.818982')
# 2025-12-02 14:47:52,819 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,819 INFO sqlalchemy.engine.Engine [cached since 0.02991s ago] (2, 'FEM', 1, 0)
#   + FEM: Female
# 2025-12-02 14:47:52,820 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,820 INFO sqlalchemy.engine.Engine [cached since 0.02888s ago] (2, 'FEM', 'Female', None, 3, 1, '2025-12-02 20:47:52.820407', '2025-12-02 20:47:52.820409')
# 2025-12-02 14:47:52,820 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,821 INFO sqlalchemy.engine.Engine [cached since 2.994s ago] ('Color', 1, 0)
#
# Color:
# 2025-12-02 14:47:52,822 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,822 INFO sqlalchemy.engine.Engine [cached since 0.0328s ago] (3, 'CLNAN', 1, 0)
#   + CLNAN: NA
# 2025-12-02 14:47:52,823 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,823 INFO sqlalchemy.engine.Engine [cached since 0.03218s ago] (3, 'CLNAN', 'NA', None, 0, 1, '2025-12-02 20:47:52.823616', '2025-12-02 20:47:52.823617')
# 2025-12-02 14:47:52,824 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,824 INFO sqlalchemy.engine.Engine [cached since 0.03456s ago] (3, 'WHT', 1, 0)
#   + WHT: White
# 2025-12-02 14:47:52,825 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,825 INFO sqlalchemy.engine.Engine [cached since 0.03351s ago] (3, 'WHT', 'White', None, 1, 1, '2025-12-02 20:47:52.825075', '2025-12-02 20:47:52.825077')
# 2025-12-02 14:47:52,825 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,825 INFO sqlalchemy.engine.Engine [cached since 0.03575s ago] (3, 'BLK', 1, 0)
#   + BLK: Black
# 2025-12-02 14:47:52,826 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,826 INFO sqlalchemy.engine.Engine [cached since 0.03455s ago] (3, 'BLK', 'Black', None, 2, 1, '2025-12-02 20:47:52.826128', '2025-12-02 20:47:52.826129')
# 2025-12-02 14:47:52,826 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,816 INFO sqlalchemy.engine.Engine [cached since 0.02519s ago] (2, 'FTNAN', 'Not Applicable', None, 0, 1, '2025-12-02 20:47:52.816755', '2025-12-02 20:47:52.816757')
# 2025-12-02 14:47:52,817 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,817 INFO sqlalchemy.engine.Engine [cached since 0.02733s ago] (2, 'USX', 1, 0)
#   + USX: Unisex
# 2025-12-02 14:47:52,817 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,817 INFO sqlalchemy.engine.Engine [cached since 0.02616s ago] (2, 'USX', 'Unisex', None, 1, 1, '2025-12-02 20:47:52.817728', '2025-12-02 20:47:52.817730')
# 2025-12-02 14:47:52,818 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,818 INFO sqlalchemy.engine.Engine [cached since 0.0284s ago] (2, 'MLE', 1, 0)
#   + MLE: Male
# 2025-12-02 14:47:52,819 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,819 INFO sqlalchemy.engine.Engine [cached since 0.02747s ago] (2, 'MLE', 'Male', None, 2, 1, '2025-12-02 20:47:52.818980', '2025-12-02 20:47:52.818982')
# 2025-12-02 14:47:52,819 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,819 INFO sqlalchemy.engine.Engine [cached since 0.02991s ago] (2, 'FEM', 1, 0)
#   + FEM: Female
# 2025-12-02 14:47:52,820 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,820 INFO sqlalchemy.engine.Engine [cached since 0.02888s ago] (2, 'FEM', 'Female', None, 3, 1, '2025-12-02 20:47:52.820407', '2025-12-02 20:47:52.820409')
# 2025-12-02 14:47:52,820 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,821 INFO sqlalchemy.engine.Engine [cached since 2.994s ago] ('Color', 1, 0)
#
# Color:
# 2025-12-02 14:47:52,822 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,822 INFO sqlalchemy.engine.Engine [cached since 0.0328s ago] (3, 'CLNAN', 1, 0)
#   + CLNAN: NA
# 2025-12-02 14:47:52,823 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,823 INFO sqlalchemy.engine.Engine [cached since 0.03218s ago] (3, 'CLNAN', 'NA', None, 0, 1, '2025-12-02 20:47:52.823616', '2025-12-02 20:47:52.823617')
# 2025-12-02 14:47:52,824 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,824 INFO sqlalchemy.engine.Engine [cached since 0.03456s ago] (3, 'WHT', 1, 0)
#   + WHT: White
# 2025-12-02 14:47:52,825 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,825 INFO sqlalchemy.engine.Engine [cached since 0.03351s ago] (3, 'WHT', 'White', None, 1, 1, '2025-12-02 20:47:52.825075', '2025-12-02 20:47:52.825077')
# 2025-12-02 14:47:52,825 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,825 INFO sqlalchemy.engine.Engine [cached since 0.03575s ago] (3, 'BLK', 1, 0)
#   + BLK: Black
# ...
# 2025-12-02 14:47:52,877 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,877 INFO sqlalchemy.engine.Engine [cached since 0.08771s ago] (5, 'CFF', 1, 0)
#   + CFF: Carbon Fiber - Forged
# 2025-12-02 14:47:52,878 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,878 INFO sqlalchemy.engine.Engine [cached since 0.08661s ago] (5, 'CFF', 'Carbon Fiber - Forged', None, 8, 1, '2025-12-02 20:47:52.878173', '2025-12-02 20:47:52.878174')
#   + BLD: Blend
# 2025-12-02 14:47:52,868 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,869 INFO sqlalchemy.engine.Engine [cached since 0.07758s ago] (5, 'BLD', 'Blend', None, 3, 1, '2025-12-02 20:47:52.868606', '2025-12-02 20:47:52.868611')
# 2025-12-02 14:47:52,870 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,871 INFO sqlalchemy.engine.Engine [cached since 0.08103s ago] (5, 'LTR', 1, 0)
#   + LTR: Leather
# 2025-12-02 14:47:52,872 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,872 INFO sqlalchemy.engine.Engine [cached since 0.0808s ago] (5, 'LTR', 'Leather', None, 4, 1, '2025-12-02 20:47:52.872300', '2025-12-02 20:47:52.872303')
# 2025-12-02 14:47:52,873 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,873 INFO sqlalchemy.engine.Engine [cached since 0.08334s ago] (5, 'MTL', 1, 0)
#   + MTL: Metal
# 2025-12-02 14:47:52,873 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,874 INFO sqlalchemy.engine.Engine [cached since 0.08229s ago] (5, 'MTL', 'Metal', None, 5, 1, '2025-12-02 20:47:52.873828', '2025-12-02 20:47:52.873834')
# 2025-12-02 14:47:52,874 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,874 INFO sqlalchemy.engine.Engine [cached since 0.08451s ago] (5, 'FGL', 1, 0)
#   + FGL: Fiberglass
# 2025-12-02 14:47:52,875 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,875 INFO sqlalchemy.engine.Engine [cached since 0.08358s ago] (5, 'FGL', 'Fiberglass', None, 6, 1, '2025-12-02 20:47:52.875141', '2025-12-02 20:47:52.875143')
# 2025-12-02 14:47:52,875 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,875 INFO sqlalchemy.engine.Engine [cached since 0.086s ago] (5, 'CFW', 1, 0)
#   + CFW: Carbon Fiber - Weave
# 2025-12-02 14:47:52,876 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,877 INFO sqlalchemy.engine.Engine [cached since 0.08547s ago] (5, 'CFW', 'Carbon Fiber - Weave', None, 7, 1, '2025-12-02 20:47:52.876474', '2025-12-02 20:47:52.876476')
# 2025-12-02 14:47:52,877 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,877 INFO sqlalchemy.engine.Engine [cached since 0.08771s ago] (5, 'CFF', 1, 0)
#   + CFF: Carbon Fiber - Forged
# 2025-12-02 14:47:52,878 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,878 INFO sqlalchemy.engine.Engine [cached since 0.08661s ago] (5, 'CFF', 'Carbon Fiber - Forged', None, 8, 1, '2025-12-02 20:47:52.878173', '2025-12-02 20:47:52.878174')
# 2025-12-02 14:47:52,878 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,879 INFO sqlalchemy.engine.Engine [cached since 3.052s ago] ('Scent', 1, 0)
#
# Scent:
# 2025-12-02 14:47:52,879 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,880 INFO sqlalchemy.engine.Engine [cached since 0.09016s ago] (6, 'STNAN', 1, 0)
#   + STNAN: Not Applicable
# 2025-12-02 14:47:52,881 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,882 INFO sqlalchemy.engine.Engine [cached since 0.09029s ago] (6, 'STNAN', 'Not Applicable', None, 0, 1, '2025-12-02 20:47:52.881397', '2025-12-02 20:47:52.881403')
# 2025-12-02 14:47:52,882 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,883 INFO sqlalchemy.engine.Engine [cached since 0.09319s ago] (6, 'CLL', 1, 0)
#   + CLL: Callahan Leather
# 2025-12-02 14:47:52,884 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,885 INFO sqlalchemy.engine.Engine [cached since 0.09346s ago] (6, 'CLL', 'Callahan Leather', None, 1, 1, '2025-12-02 20:47:52.884464', '2025-12-02 20:47:52.884471')
# 2025-12-02 14:47:52,886 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,886 INFO sqlalchemy.engine.Engine [cached since 0.09697s ago] (6, 'VLL', 1, 0)
#   + VLL: Vanilla Leather
# 2025-12-02 14:47:52,888 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,888 INFO sqlalchemy.engine.Engine [cached since 0.09661s ago] (6, 'VLL', 'Vanilla Leather', None, 2, 1, '2025-12-02 20:47:52.888157', '2025-12-02 20:47:52.888159')
# 2025-12-02 14:47:52,888 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,878 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,879 INFO sqlalchemy.engine.Engine [cached since 3.052s ago] ('Scent', 1, 0)
#
# Scent:
# 2025-12-02 14:47:52,879 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,880 INFO sqlalchemy.engine.Engine [cached since 0.09016s ago] (6, 'STNAN', 1, 0)
#   + STNAN: Not Applicable
# 2025-12-02 14:47:52,881 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,882 INFO sqlalchemy.engine.Engine [cached since 0.09029s ago] (6, 'STNAN', 'Not Applicable', None, 0, 1, '2025-12-02 20:47:52.881397', '2025-12-02 20:47:52.881403')
# 2025-12-02 14:47:52,882 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,883 INFO sqlalchemy.engine.Engine [cached since 0.09319s ago] (6, 'CLL', 1, 0)
#   + CLL: Callahan Leather
# 2025-12-02 14:47:52,884 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,885 INFO sqlalchemy.engine.Engine [cached since 0.09346s ago] (6, 'CLL', 'Callahan Leather', None, 1, 1, '2025-12-02 20:47:52.884464', '2025-12-02 20:47:52.884471')
# 2025-12-02 14:47:52,886 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,886 INFO sqlalchemy.engine.Engine [cached since 0.09697s ago] (6, 'VLL', 1, 0)
#   + VLL: Vanilla Leather
# 2025-12-02 14:47:52,888 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,888 INFO sqlalchemy.engine.Engine [cached since 0.09661s ago] (6, 'VLL', 'Vanilla Leather', None, 2, 1, '2025-12-02 20:47:52.888157', '2025-12-02 20:47:52.888159')
# 2025-12-02 14:47:52,888 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.feature_type_id = ? AND features.code = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:52,888 INFO sqlalchemy.engine.Engine [cached since 0.09894s ago] (6, 'CBC', 1, 0)
#   + CBC: Cowboy Cologne
# 2025-12-02 14:47:52,889 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,889 INFO sqlalchemy.engine.Engine [cached since 0.09769s ago] (6, 'CBC', 'Cowboy Cologne', None, 3, 1, '2025-12-02 20:47:52.889271', '2025-12-02 20:47:52.889272')
# 2025-12-02 14:47:52,889 INFO sqlalchemy.engine.Engine COMMIT
#
# ✓ 52 features migrated successfully!
# 2025-12-02 14:47:52,888 INFO sqlalchemy.engine.Engine [cached since 0.09894s ago] (6, 'CBC', 1, 0)
#   + CBC: Cowboy Cologne
# 2025-12-02 14:47:52,889 INFO sqlalchemy.engine.Engine INSERT INTO features (feature_type_id, code, name, description, sort_order, is_active, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:52,889 INFO sqlalchemy.engine.Engine [cached since 0.09769s ago] (6, 'CBC', 'Cowboy Cologne', None, 3, 1, '2025-12-02 20:47:52.889271', '2025-12-02 20:47:52.889272')
# 2025-12-02 14:47:52,889 INFO sqlalchemy.engine.Engine COMMIT
#
# ✓ 52 features migrated successfully!

# %% [markdown]
# ### Step 5: Migrate Products
#
# Load all products from the Product_Catalog.

# %%
session = Session()

try:
    products_added = 0
    
    for idx, row in catalog_tables['Product_Catalog'].iterrows():
        # Find the category
        category = session.query(Category).filter_by(
            category=row['Main_Category'],
            subcategory=row['Sub_Category']
        ).first()
        
        if not category:
            print(f"✗ Category not found for {row['Name']}, skipping...")
            continue
        
        # Check if product already exists
        existing = session.query(Product).filter_by(product_name=row['Name']).first()
        
        if not existing:
            product = Product(
                product_name=row['Name'],
                category_id=category.id,
                description=None,  # Add if you have description field
                base_price=None,   # Add if you have price field
                status='active'
            )
            session.add(product)
            products_added += 1
            print(f"  + {row['Name']}")
        else:
            print(f"  - {row['Name']} (already exists)")
    
    session.commit()
    print(f"\n✓ {products_added} products migrated successfully!")
    
except Exception as e:
    session.rollback()
    print(f"✗ Error migrating products: {e}")
    raise
finally:
    session.close()
# Out:
# 2025-12-02 14:47:57,627 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-02 14:47:57,628 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,629 INFO sqlalchemy.engine.Engine [cached since 77.73s ago] ('Shirt', 'Tee Shirt', 1, 0)
# 2025-12-02 14:47:57,630 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,630 INFO sqlalchemy.engine.Engine [generated in 0.00035s] ('Bandit Banquet Tee', 1, 0)
#   + Bandit Banquet Tee
# 2025-12-02 14:47:57,632 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,632 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Bandit Banquet Tee', 1, None, None, 'active', '2025-12-02 20:47:57.632166', '2025-12-02 20:47:57.632170')
# 2025-12-02 14:47:57,633 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,633 INFO sqlalchemy.engine.Engine [cached since 77.73s ago] ('Shirt', 'Tee Shirt', 1, 0)
# 2025-12-02 14:47:57,634 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,634 INFO sqlalchemy.engine.Engine [cached since 0.003911s ago] ('Bandit Truck Wreath Tee', 1, 0)
#   + Bandit Truck Wreath Tee
# 2025-12-02 14:47:57,635 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,636 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Bandit Truck Wreath Tee', 1, None, None, 'active', '2025-12-02 20:47:57.635340', '2025-12-02 20:47:57.635344')
# 2025-12-02 14:47:57,637 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,628 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,629 INFO sqlalchemy.engine.Engine [cached since 77.73s ago] ('Shirt', 'Tee Shirt', 1, 0)
# 2025-12-02 14:47:57,630 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,630 INFO sqlalchemy.engine.Engine [generated in 0.00035s] ('Bandit Banquet Tee', 1, 0)
#   + Bandit Banquet Tee
# 2025-12-02 14:47:57,632 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,632 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Bandit Banquet Tee', 1, None, None, 'active', '2025-12-02 20:47:57.632166', '2025-12-02 20:47:57.632170')
# 2025-12-02 14:47:57,633 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,633 INFO sqlalchemy.engine.Engine [cached since 77.73s ago] ('Shirt', 'Tee Shirt', 1, 0)
# 2025-12-02 14:47:57,634 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,634 INFO sqlalchemy.engine.Engine [cached since 0.003911s ago] ('Bandit Truck Wreath Tee', 1, 0)
#   + Bandit Truck Wreath Tee
# 2025-12-02 14:47:57,635 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,636 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Bandit Truck Wreath Tee', 1, None, None, 'active', '2025-12-02 20:47:57.635340', '2025-12-02 20:47:57.635344')
# 2025-12-02 14:47:57,637 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,637 INFO sqlalchemy.engine.Engine [cached since 77.73s ago] ('Shirt', 'Tee Shirt', 1, 0)
# 2025-12-02 14:47:57,638 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,638 INFO sqlalchemy.engine.Engine [cached since 0.008095s ago] ('Bandit Truck Logo Tee', 1, 0)
#   + Bandit Truck Logo Tee
# 2025-12-02 14:47:57,639 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,639 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Bandit Truck Logo Tee', 1, None, None, 'active', '2025-12-02 20:47:57.639244', '2025-12-02 20:47:57.639246')
# 2025-12-02 14:47:57,640 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,640 INFO sqlalchemy.engine.Engine [cached since 77.74s ago] ('Shirt', 'Tee Shirt', 1, 0)
# 2025-12-02 14:47:57,640 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,641 INFO sqlalchemy.engine.Engine [cached since 0.01068s ago] ('Legendary Tee', 1, 0)
#   + Legendary Tee
# 2025-12-02 14:47:57,642 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,642 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Legendary Tee', 1, None, None, 'active', '2025-12-02 20:47:57.642034', '2025-12-02 20:47:57.642037')
# 2025-12-02 14:47:57,642 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,643 INFO sqlalchemy.engine.Engine [cached since 77.74s ago] ('Shirt', 'Long Sleeve Tee Shirt', 1, 0)
# 2025-12-02 14:47:57,643 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,644 INFO sqlalchemy.engine.Engine [cached since 0.01358s ago] ('Legendary Long Sleeve Tee', 1, 0)
#   + Legendary Long Sleeve Tee
# 2025-12-02 14:47:57,644 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,645 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Legendary Long Sleeve Tee', 2, None, None, 'active', '2025-12-02 20:47:57.644838', '2025-12-02 20:47:57.644841')
# 2025-12-02 14:47:57,645 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,645 INFO sqlalchemy.engine.Engine [cached since 77.74s ago] ('Shirt', 'Polo', 1, 0)
# 2025-12-02 14:47:57,646 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,646 INFO sqlalchemy.engine.Engine [cached since 0.01596s ago] ('Legendary Polo', 1, 0)
#   + Legendary Polo
# 2025-12-02 14:47:57,646 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,647 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Legendary Polo', 3, None, None, 'active', '2025-12-02 20:47:57.646922', '2025-12-02 20:47:57.646924')
# 2025-12-02 14:47:57,647 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,637 INFO sqlalchemy.engine.Engine [cached since 77.73s ago] ('Shirt', 'Tee Shirt', 1, 0)
# 2025-12-02 14:47:57,638 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,638 INFO sqlalchemy.engine.Engine [cached since 0.008095s ago] ('Bandit Truck Logo Tee', 1, 0)
#   + Bandit Truck Logo Tee
# 2025-12-02 14:47:57,639 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,639 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Bandit Truck Logo Tee', 1, None, None, 'active', '2025-12-02 20:47:57.639244', '2025-12-02 20:47:57.639246')
# 2025-12-02 14:47:57,640 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,640 INFO sqlalchemy.engine.Engine [cached since 77.74s ago] ('Shirt', 'Tee Shirt', 1, 0)
# 2025-12-02 14:47:57,640 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,641 INFO sqlalchemy.engine.Engine [cached since 0.01068s ago] ('Legendary Tee', 1, 0)
#   + Legendary Tee
# 2025-12-02 14:47:57,642 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,642 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Legendary Tee', 1, None, None, 'active', '2025-12-02 20:47:57.642034', '2025-12-02 20:47:57.642037')
# 2025-12-02 14:47:57,642 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,643 INFO sqlalchemy.engine.Engine [cached since 77.74s ago] ('Shirt', 'Long Sleeve Tee Shirt', 1, 0)
# 2025-12-02 14:47:57,643 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,644 INFO sqlalchemy.engine.Engine [cached since 0.01358s ago] ('Legendary Long Sleeve Tee', 1, 0)
#   + Legendary Long Sleeve Tee
# 2025-12-02 14:47:57,644 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,645 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Legendary Long Sleeve Tee', 2, None, None, 'active', '2025-12-02 20:47:57.644838', '2025-12-02 20:47:57.644841')
# 2025-12-02 14:47:57,645 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,645 INFO sqlalchemy.engine.Engine [cached since 77.74s ago] ('Shirt', 'Polo', 1, 0)
# 2025-12-02 14:47:57,646 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,646 INFO sqlalchemy.engine.Engine [cached since 0.01596s ago] ('Legendary Polo', 1, 0)
#   + Legendary Polo
# 2025-12-02 14:47:57,646 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,647 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Legendary Polo', 3, None, None, 'active', '2025-12-02 20:47:57.646922', '2025-12-02 20:47:57.646924')
# 2025-12-02 14:47:57,647 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,647 INFO sqlalchemy.engine.Engine [cached since 77.74s ago] ('Outerwear', 'Sweater', 1, 0)
# 2025-12-02 14:47:57,648 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,648 INFO sqlalchemy.engine.Engine [cached since 0.01787s ago] ('Legendary Sweater', 1, 0)
#   + Legendary Sweater
# 2025-12-02 14:47:57,648 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,649 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Legendary Sweater', 4, None, None, 'active', '2025-12-02 20:47:57.648896', '2025-12-02 20:47:57.648898')
# 2025-12-02 14:47:57,649 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,649 INFO sqlalchemy.engine.Engine [cached since 77.75s ago] ('Outerwear', 'Sweater', 1, 0)
# 2025-12-02 14:47:57,650 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,650 INFO sqlalchemy.engine.Engine [cached since 0.01987s ago] ('Bandit Truck Wreath Sweater', 1, 0)
#   + Bandit Truck Wreath Sweater
# 2025-12-02 14:47:57,650 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,651 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Bandit Truck Wreath Sweater', 4, None, None, 'active', '2025-12-02 20:47:57.650957', '2025-12-02 20:47:57.650959')
# 2025-12-02 14:47:57,651 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,651 INFO sqlalchemy.engine.Engine [cached since 77.75s ago] ('Outerwear', 'Hoody', 1, 0)
# 2025-12-02 14:47:57,652 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,652 INFO sqlalchemy.engine.Engine [cached since 0.02215s ago] ('Legendary Hoody', 1, 0)
#   + Legendary Hoody
# 2025-12-02 14:47:57,653 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,653 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Legendary Hoody', 5, None, None, 'active', '2025-12-02 20:47:57.653287', '2025-12-02 20:47:57.653289')
# 2025-12-02 14:47:57,653 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,654 INFO sqlalchemy.engine.Engine [cached since 77.75s ago] ('Outerwear', 'Jacket', 1, 0)
# 2025-12-02 14:47:57,654 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,654 INFO sqlalchemy.engine.Engine [cached since 0.02422s ago] ('Bandit Truck Jacket', 1, 0)
#   + Bandit Truck Jacket
# 2025-12-02 14:47:57,655 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,655 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Bandit Truck Jacket', 6, None, None, 'active', '2025-12-02 20:47:57.655177', '2025-12-02 20:47:57.655179')
# 2025-12-02 14:47:57,655 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,655 INFO sqlalchemy.engine.Engine [cached since 77.75s ago] ('Outerwear', 'Jacket', 1, 0)
# 2025-12-02 14:47:57,656 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,656 INFO sqlalchemy.engine.Engine [cached since 0.02601s ago] ('Legendary Jacket', 1, 0)
#   + Legendary Jacket
# 2025-12-02 14:47:57,657 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,657 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Legendary Jacket', 6, None, None, 'active', '2025-12-02 20:47:57.656995', '2025-12-02 20:47:57.656997')
# 2025-12-02 14:47:57,657 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,647 INFO sqlalchemy.engine.Engine [cached since 77.74s ago] ('Outerwear', 'Sweater', 1, 0)
# 2025-12-02 14:47:57,648 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,648 INFO sqlalchemy.engine.Engine [cached since 0.01787s ago] ('Legendary Sweater', 1, 0)
#   + Legendary Sweater
# 2025-12-02 14:47:57,648 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,649 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Legendary Sweater', 4, None, None, 'active', '2025-12-02 20:47:57.648896', '2025-12-02 20:47:57.648898')
# 2025-12-02 14:47:57,649 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,649 INFO sqlalchemy.engine.Engine [cached since 77.75s ago] ('Outerwear', 'Sweater', 1, 0)
# 2025-12-02 14:47:57,650 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,650 INFO sqlalchemy.engine.Engine [cached since 0.01987s ago] ('Bandit Truck Wreath Sweater', 1, 0)
#   + Bandit Truck Wreath Sweater
# 2025-12-02 14:47:57,650 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,651 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Bandit Truck Wreath Sweater', 4, None, None, 'active', '2025-12-02 20:47:57.650957', '2025-12-02 20:47:57.650959')
# 2025-12-02 14:47:57,651 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,651 INFO sqlalchemy.engine.Engine [cached since 77.75s ago] ('Outerwear', 'Hoody', 1, 0)
# 2025-12-02 14:47:57,652 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,652 INFO sqlalchemy.engine.Engine [cached since 0.02215s ago] ('Legendary Hoody', 1, 0)
#   + Legendary Hoody
# 2025-12-02 14:47:57,653 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,653 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Legendary Hoody', 5, None, None, 'active', '2025-12-02 20:47:57.653287', '2025-12-02 20:47:57.653289')
# 2025-12-02 14:47:57,653 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,654 INFO sqlalchemy.engine.Engine [cached since 77.75s ago] ('Outerwear', 'Jacket', 1, 0)
# 2025-12-02 14:47:57,654 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,654 INFO sqlalchemy.engine.Engine [cached since 0.02422s ago] ('Bandit Truck Jacket', 1, 0)
#   + Bandit Truck Jacket
# 2025-12-02 14:47:57,655 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,655 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Bandit Truck Jacket', 6, None, None, 'active', '2025-12-02 20:47:57.655177', '2025-12-02 20:47:57.655179')
# 2025-12-02 14:47:57,655 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,655 INFO sqlalchemy.engine.Engine [cached since 77.75s ago] ('Outerwear', 'Jacket', 1, 0)
# 2025-12-02 14:47:57,656 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,656 INFO sqlalchemy.engine.Engine [cached since 0.02601s ago] ('Legendary Jacket', 1, 0)
#   + Legendary Jacket
# 2025-12-02 14:47:57,657 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,657 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Legendary Jacket', 6, None, None, 'active', '2025-12-02 20:47:57.656995', '2025-12-02 20:47:57.656997')
# 2025-12-02 14:47:57,657 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,657 INFO sqlalchemy.engine.Engine [cached since 77.75s ago] ('Headwear', 'Trucker Hat', 1, 0)
# 2025-12-02 14:47:57,657 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,658 INFO sqlalchemy.engine.Engine [cached since 0.02769s ago] ('Legendary Trucker Hat', 1, 0)
#   + Legendary Trucker Hat
# 2025-12-02 14:47:57,658 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,658 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Legendary Trucker Hat', 7, None, None, 'active', '2025-12-02 20:47:57.658670', '2025-12-02 20:47:57.658672')
# 2025-12-02 14:47:57,659 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,659 INFO sqlalchemy.engine.Engine [cached since 77.76s ago] ('Headwear', 'Trucker Hat', 1, 0)
# 2025-12-02 14:47:57,659 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,659 INFO sqlalchemy.engine.Engine [cached since 0.02948s ago] ('Bandit Truck Trucker Hat', 1, 0)
#   + Bandit Truck Trucker Hat
# 2025-12-02 14:47:57,660 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,660 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Bandit Truck Trucker Hat', 7, None, None, 'active', '2025-12-02 20:47:57.660340', '2025-12-02 20:47:57.660342')
# 2025-12-02 14:47:57,660 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,660 INFO sqlalchemy.engine.Engine [cached since 77.76s ago] ('Headwear', 'Ball Cap', 1, 0)
# 2025-12-02 14:47:57,661 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,661 INFO sqlalchemy.engine.Engine [cached since 0.03102s ago] ('Legendary Distressed Hat', 1, 0)
#   + Legendary Distressed Hat
# 2025-12-02 14:47:57,661 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,662 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Legendary Distressed Hat', 8, None, None, 'active', '2025-12-02 20:47:57.661877', '2025-12-02 20:47:57.661879')
# 2025-12-02 14:47:57,662 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,662 INFO sqlalchemy.engine.Engine [cached since 77.76s ago] ('Headwear', 'Flex Fit Hat', 1, 0)
# 2025-12-02 14:47:57,663 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,663 INFO sqlalchemy.engine.Engine [cached since 0.03311s ago] ('Legendary Flex Fit Hat', 1, 0)
#   + Legendary Flex Fit Hat
# 2025-12-02 14:47:57,664 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,664 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Legendary Flex Fit Hat', 9, None, None, 'active', '2025-12-02 20:47:57.664346', '2025-12-02 20:47:57.664348')
# 2025-12-02 14:47:57,664 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,664 INFO sqlalchemy.engine.Engine [cached since 77.76s ago] ('Headwear', 'Flex Fit Hat', 1, 0)
# 2025-12-02 14:47:57,665 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,665 INFO sqlalchemy.engine.Engine [cached since 0.03502s ago] ('Bandit Truck Flex Fit Hat', 1, 0)
#   + Bandit Truck Flex Fit Hat
# 2025-12-02 14:47:57,665 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,666 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Bandit Truck Flex Fit Hat', 9, None, None, 'active', '2025-12-02 20:47:57.665938', '2025-12-02 20:47:57.665939')
# 2025-12-02 14:47:57,666 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,666 INFO sqlalchemy.engine.Engine [cached since 77.76s ago] ('Accessories', 'Air Freshener', 1, 0)
# 2025-12-02 14:47:57,666 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,667 INFO sqlalchemy.engine.Engine [cached since 0.03665s ago] ('Leather Air Freshener', 1, 0)
#   + Leather Air Freshener
# 2025-12-02 14:47:57,667 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,657 INFO sqlalchemy.engine.Engine [cached since 77.75s ago] ('Headwear', 'Trucker Hat', 1, 0)
# 2025-12-02 14:47:57,657 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,658 INFO sqlalchemy.engine.Engine [cached since 0.02769s ago] ('Legendary Trucker Hat', 1, 0)
#   + Legendary Trucker Hat
# 2025-12-02 14:47:57,658 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,658 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Legendary Trucker Hat', 7, None, None, 'active', '2025-12-02 20:47:57.658670', '2025-12-02 20:47:57.658672')
# 2025-12-02 14:47:57,659 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,659 INFO sqlalchemy.engine.Engine [cached since 77.76s ago] ('Headwear', 'Trucker Hat', 1, 0)
# 2025-12-02 14:47:57,659 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,659 INFO sqlalchemy.engine.Engine [cached since 0.02948s ago] ('Bandit Truck Trucker Hat', 1, 0)
#   + Bandit Truck Trucker Hat
# 2025-12-02 14:47:57,660 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,660 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Bandit Truck Trucker Hat', 7, None, None, 'active', '2025-12-02 20:47:57.660340', '2025-12-02 20:47:57.660342')
# 2025-12-02 14:47:57,660 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,660 INFO sqlalchemy.engine.Engine [cached since 77.76s ago] ('Headwear', 'Ball Cap', 1, 0)
# 2025-12-02 14:47:57,661 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,661 INFO sqlalchemy.engine.Engine [cached since 0.03102s ago] ('Legendary Distressed Hat', 1, 0)
#   + Legendary Distressed Hat
# 2025-12-02 14:47:57,661 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,662 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Legendary Distressed Hat', 8, None, None, 'active', '2025-12-02 20:47:57.661877', '2025-12-02 20:47:57.661879')
# 2025-12-02 14:47:57,662 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,662 INFO sqlalchemy.engine.Engine [cached since 77.76s ago] ('Headwear', 'Flex Fit Hat', 1, 0)
# 2025-12-02 14:47:57,663 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,663 INFO sqlalchemy.engine.Engine [cached since 0.03311s ago] ('Legendary Flex Fit Hat', 1, 0)
#   + Legendary Flex Fit Hat
# 2025-12-02 14:47:57,664 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,664 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Legendary Flex Fit Hat', 9, None, None, 'active', '2025-12-02 20:47:57.664346', '2025-12-02 20:47:57.664348')
# 2025-12-02 14:47:57,664 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,664 INFO sqlalchemy.engine.Engine [cached since 77.76s ago] ('Headwear', 'Flex Fit Hat', 1, 0)
# 2025-12-02 14:47:57,665 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,665 INFO sqlalchemy.engine.Engine [cached since 0.03502s ago] ('Bandit Truck Flex Fit Hat', 1, 0)
#   + Bandit Truck Flex Fit Hat
# 2025-12-02 14:47:57,665 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,666 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Bandit Truck Flex Fit Hat', 9, None, None, 'active', '2025-12-02 20:47:57.665938', '2025-12-02 20:47:57.665939')
# 2025-12-02 14:47:57,666 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,666 INFO sqlalchemy.engine.Engine [cached since 77.76s ago] ('Accessories', 'Air Freshener', 1, 0)
# 2025-12-02 14:47:57,666 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,667 INFO sqlalchemy.engine.Engine [cached since 0.03665s ago] ('Leather Air Freshener', 1, 0)
#   + Leather Air Freshener
# 2025-12-02 14:47:57,667 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,667 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Leather Air Freshener', 10, None, None, 'active', '2025-12-02 20:47:57.667488', '2025-12-02 20:47:57.667490')
# 2025-12-02 14:47:57,667 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,668 INFO sqlalchemy.engine.Engine [cached since 77.76s ago] ('Accessories', 'Keychain', 1, 0)
# 2025-12-02 14:47:57,668 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,668 INFO sqlalchemy.engine.Engine [cached since 0.03815s ago] ('Collectible Gold Keychain', 1, 0)
#   + Collectible Gold Keychain
# 2025-12-02 14:47:57,668 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,669 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Collectible Gold Keychain', 11, None, None, 'active', '2025-12-02 20:47:57.668955', '2025-12-02 20:47:57.668956')
# 2025-12-02 14:47:57,669 INFO sqlalchemy.engine.Engine COMMIT
#
# ✓ 18 products migrated successfully!
# 2025-12-02 14:47:57,667 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Leather Air Freshener', 10, None, None, 'active', '2025-12-02 20:47:57.667488', '2025-12-02 20:47:57.667490')
# 2025-12-02 14:47:57,667 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.category = ? AND categories.subcategory = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,668 INFO sqlalchemy.engine.Engine [cached since 77.76s ago] ('Accessories', 'Keychain', 1, 0)
# 2025-12-02 14:47:57,668 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:47:57,668 INFO sqlalchemy.engine.Engine [cached since 0.03815s ago] ('Collectible Gold Keychain', 1, 0)
#   + Collectible Gold Keychain
# 2025-12-02 14:47:57,668 INFO sqlalchemy.engine.Engine INSERT INTO products (product_name, category_id, description, base_price, status, created_at, updated_at) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2025-12-02 14:47:57,669 INFO sqlalchemy.engine.Engine [cached since 356.3s ago] ('Collectible Gold Keychain', 11, None, None, 'active', '2025-12-02 20:47:57.668955', '2025-12-02 20:47:57.668956')
# 2025-12-02 14:47:57,669 INFO sqlalchemy.engine.Engine COMMIT
#
# ✓ 18 products migrated successfully!

# %% [markdown]
# ### Step 6: Link Products to Features
#
# Create Product_Features relationships based on the catalog.

# %%
session = Session()

try:
    links_added = 0
    exclude_sheets = ['Product_Catalog', 'Prefix_Codes', 'Main_Category', 'Sub_Category']
    feature_columns = [col for col in catalog_tables['Product_Catalog'].columns 
                      if col not in ['Index', 'Main_Category', 'Sub_Category', 'Name']]
    
    for idx, row in catalog_tables['Product_Catalog'].iterrows():
        # Get the product
        product = session.query(Product).filter_by(product_name=row['Name']).first()
        
        if not product:
            continue
        
        # For each feature column, parse the values and create links
        for feature_col in feature_columns:
            feature_values_str = str(row[feature_col])
            
            # Skip empty or None values
            if pd.isna(row[feature_col]) or feature_values_str == 'nan':
                continue
            
            # Parse comma-separated values
            feature_value_names = [v.strip() for v in feature_values_str.split(',')]
            
            # Get the feature type
            feature_type = session.query(FeatureType).filter_by(feature_type=feature_col).first()
            
            if not feature_type:
                continue
            
            # Link each feature value to the product
            for feature_name in feature_value_names:
                # Find the feature by name and type
                feature = session.query(Feature).join(FeatureType).filter(
                    Feature.name == feature_name,
                    FeatureType.id == feature_type.id
                ).first()
                
                if feature:
                    # Check if link already exists
                    existing_link = session.query(ProductFeature).filter_by(
                        product_id=product.id,
                        feature_id=feature.id
                    ).first()
                    
                    if not existing_link:
                        link = ProductFeature(
                            product_id=product.id,
                            feature_id=feature.id
                        )
                        session.add(link)
                        links_added += 1
    
    session.commit()
    print(f"✓ {links_added} product-feature links created!")
    
except Exception as e:
    session.rollback()
    print(f"✗ Error creating product-feature links: {e}")
    raise
finally:
    session.close()
# Out:
# 2025-12-02 14:48:02,422 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-02 14:48:02,423 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,424 INFO sqlalchemy.engine.Engine [cached since 4.794s ago] ('Bandit Banquet Tee', 1, 0)
# 2025-12-02 14:48:02,425 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,425 INFO sqlalchemy.engine.Engine [cached since 12.6s ago] ('Size', 1, 0)
# 2025-12-02 14:48:02,426 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,427 INFO sqlalchemy.engine.Engine [generated in 0.00036s] ('Child Small', 1, 1, 0)
# 2025-12-02 14:48:02,429 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,429 INFO sqlalchemy.engine.Engine [generated in 0.00061s] (1, 2, 1, 0)
# 2025-12-02 14:48:02,430 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,431 INFO sqlalchemy.engine.Engine [generated in 0.00045s] (1, 2, '2025-12-02 20:48:02.430877')
# 2025-12-02 14:48:02,432 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,432 INFO sqlalchemy.engine.Engine [cached since 0.005923s ago] ('Child Medium', 1, 1, 0)
# 2025-12-02 14:48:02,433 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,433 INFO sqlalchemy.engine.Engine [cached since 0.004499s ago] (1, 3, 1, 0)
# 2025-12-02 14:48:02,423 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
# WHERE products.product_name = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,424 INFO sqlalchemy.engine.Engine [cached since 4.794s ago] ('Bandit Banquet Tee', 1, 0)
# 2025-12-02 14:48:02,425 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,425 INFO sqlalchemy.engine.Engine [cached since 12.6s ago] ('Size', 1, 0)
# 2025-12-02 14:48:02,426 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,427 INFO sqlalchemy.engine.Engine [generated in 0.00036s] ('Child Small', 1, 1, 0)
# 2025-12-02 14:48:02,429 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,429 INFO sqlalchemy.engine.Engine [generated in 0.00061s] (1, 2, 1, 0)
# 2025-12-02 14:48:02,430 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,431 INFO sqlalchemy.engine.Engine [generated in 0.00045s] (1, 2, '2025-12-02 20:48:02.430877')
# 2025-12-02 14:48:02,432 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,432 INFO sqlalchemy.engine.Engine [cached since 0.005923s ago] ('Child Medium', 1, 1, 0)
# 2025-12-02 14:48:02,433 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,433 INFO sqlalchemy.engine.Engine [cached since 0.004499s ago] (1, 3, 1, 0)
# 2025-12-02 14:48:02,434 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,434 INFO sqlalchemy.engine.Engine [cached since 0.003725s ago] (1, 3, '2025-12-02 20:48:02.434131')
# 2025-12-02 14:48:02,435 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,435 INFO sqlalchemy.engine.Engine [cached since 0.009012s ago] ('Child Large', 1, 1, 0)
# 2025-12-02 14:48:02,436 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,436 INFO sqlalchemy.engine.Engine [cached since 0.008008s ago] (1, 4, 1, 0)
# 2025-12-02 14:48:02,437 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,438 INFO sqlalchemy.engine.Engine [cached since 0.007258s ago] (1, 4, '2025-12-02 20:48:02.437718')
# 2025-12-02 14:48:02,438 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,438 INFO sqlalchemy.engine.Engine [cached since 0.01212s ago] ('Extra Small', 1, 1, 0)
# 2025-12-02 14:48:02,439 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,439 INFO sqlalchemy.engine.Engine [cached since 0.0106s ago] (1, 5, 1, 0)
# 2025-12-02 14:48:02,439 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,440 INFO sqlalchemy.engine.Engine [cached since 0.009335s ago] (1, 5, '2025-12-02 20:48:02.439945')
# 2025-12-02 14:48:02,440 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,440 INFO sqlalchemy.engine.Engine [cached since 0.01416s ago] ('Small', 1, 1, 0)
# 2025-12-02 14:48:02,441 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,441 INFO sqlalchemy.engine.Engine [cached since 0.01263s ago] (1, 6, 1, 0)
# 2025-12-02 14:48:02,442 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,442 INFO sqlalchemy.engine.Engine [cached since 0.01169s ago] (1, 6, '2025-12-02 20:48:02.442233')
# 2025-12-02 14:48:02,443 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,443 INFO sqlalchemy.engine.Engine [cached since 0.01656s ago] ('Medium', 1, 1, 0)
# 2025-12-02 14:48:02,443 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,443 INFO sqlalchemy.engine.Engine [cached since 0.01494s ago] (1, 7, 1, 0)
# 2025-12-02 14:48:02,444 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,434 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,434 INFO sqlalchemy.engine.Engine [cached since 0.003725s ago] (1, 3, '2025-12-02 20:48:02.434131')
# 2025-12-02 14:48:02,435 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,435 INFO sqlalchemy.engine.Engine [cached since 0.009012s ago] ('Child Large', 1, 1, 0)
# 2025-12-02 14:48:02,436 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,436 INFO sqlalchemy.engine.Engine [cached since 0.008008s ago] (1, 4, 1, 0)
# 2025-12-02 14:48:02,437 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,438 INFO sqlalchemy.engine.Engine [cached since 0.007258s ago] (1, 4, '2025-12-02 20:48:02.437718')
# 2025-12-02 14:48:02,438 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,438 INFO sqlalchemy.engine.Engine [cached since 0.01212s ago] ('Extra Small', 1, 1, 0)
# 2025-12-02 14:48:02,439 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,439 INFO sqlalchemy.engine.Engine [cached since 0.0106s ago] (1, 5, 1, 0)
# 2025-12-02 14:48:02,439 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,440 INFO sqlalchemy.engine.Engine [cached since 0.009335s ago] (1, 5, '2025-12-02 20:48:02.439945')
# 2025-12-02 14:48:02,440 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,440 INFO sqlalchemy.engine.Engine [cached since 0.01416s ago] ('Small', 1, 1, 0)
# 2025-12-02 14:48:02,441 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,441 INFO sqlalchemy.engine.Engine [cached since 0.01263s ago] (1, 6, 1, 0)
# 2025-12-02 14:48:02,442 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,442 INFO sqlalchemy.engine.Engine [cached since 0.01169s ago] (1, 6, '2025-12-02 20:48:02.442233')
# 2025-12-02 14:48:02,443 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,443 INFO sqlalchemy.engine.Engine [cached since 0.01656s ago] ('Medium', 1, 1, 0)
# 2025-12-02 14:48:02,443 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,443 INFO sqlalchemy.engine.Engine [cached since 0.01494s ago] (1, 7, 1, 0)
# 2025-12-02 14:48:02,444 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,444 INFO sqlalchemy.engine.Engine [cached since 0.01371s ago] (1, 7, '2025-12-02 20:48:02.444363')
# 2025-12-02 14:48:02,444 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,445 INFO sqlalchemy.engine.Engine [cached since 0.01836s ago] ('Large', 1, 1, 0)
# 2025-12-02 14:48:02,445 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,445 INFO sqlalchemy.engine.Engine [cached since 0.0168s ago] (1, 8, 1, 0)
# 2025-12-02 14:48:02,446 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,446 INFO sqlalchemy.engine.Engine [cached since 0.01549s ago] (1, 8, '2025-12-02 20:48:02.446133')
# 2025-12-02 14:48:02,446 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,446 INFO sqlalchemy.engine.Engine [cached since 0.02022s ago] ('Extra Large', 1, 1, 0)
# 2025-12-02 14:48:02,447 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,447 INFO sqlalchemy.engine.Engine [cached since 0.01862s ago] (1, 9, 1, 0)
# 2025-12-02 14:48:02,448 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,448 INFO sqlalchemy.engine.Engine [cached since 0.01749s ago] (1, 9, '2025-12-02 20:48:02.448099')
# 2025-12-02 14:48:02,448 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,448 INFO sqlalchemy.engine.Engine [cached since 0.02217s ago] ('Double Extra Large', 1, 1, 0)
# 2025-12-02 14:48:02,449 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,449 INFO sqlalchemy.engine.Engine [cached since 0.02051s ago] (1, 10, 1, 0)
# 2025-12-02 14:48:02,449 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,450 INFO sqlalchemy.engine.Engine [cached since 0.01922s ago] (1, 10, '2025-12-02 20:48:02.449835')
# 2025-12-02 14:48:02,450 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,450 INFO sqlalchemy.engine.Engine [cached since 0.02413s ago] ('Triple Extra Large', 1, 1, 0)
# 2025-12-02 14:48:02,451 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,451 INFO sqlalchemy.engine.Engine [cached since 0.02246s ago] (1, 11, 1, 0)
# 2025-12-02 14:48:02,451 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,452 INFO sqlalchemy.engine.Engine [cached since 0.0214s ago] (1, 11, '2025-12-02 20:48:02.451852')
# 2025-12-02 14:48:02,452 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,452 INFO sqlalchemy.engine.Engine [cached since 0.02618s ago] ('Quadruple Extra Large', 1, 1, 0)
# 2025-12-02 14:48:02,453 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,453 INFO sqlalchemy.engine.Engine [cached since 0.02457s ago] (1, 12, 1, 0)
# 2025-12-02 14:48:02,453 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,454 INFO sqlalchemy.engine.Engine [cached since 0.02333s ago] (1, 12, '2025-12-02 20:48:02.453893')
# 2025-12-02 14:48:02,454 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,444 INFO sqlalchemy.engine.Engine [cached since 0.01371s ago] (1, 7, '2025-12-02 20:48:02.444363')
# 2025-12-02 14:48:02,444 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,445 INFO sqlalchemy.engine.Engine [cached since 0.01836s ago] ('Large', 1, 1, 0)
# 2025-12-02 14:48:02,445 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,445 INFO sqlalchemy.engine.Engine [cached since 0.0168s ago] (1, 8, 1, 0)
# 2025-12-02 14:48:02,446 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,446 INFO sqlalchemy.engine.Engine [cached since 0.01549s ago] (1, 8, '2025-12-02 20:48:02.446133')
# 2025-12-02 14:48:02,446 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,446 INFO sqlalchemy.engine.Engine [cached since 0.02022s ago] ('Extra Large', 1, 1, 0)
# 2025-12-02 14:48:02,447 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,447 INFO sqlalchemy.engine.Engine [cached since 0.01862s ago] (1, 9, 1, 0)
# 2025-12-02 14:48:02,448 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,448 INFO sqlalchemy.engine.Engine [cached since 0.01749s ago] (1, 9, '2025-12-02 20:48:02.448099')
# 2025-12-02 14:48:02,448 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,448 INFO sqlalchemy.engine.Engine [cached since 0.02217s ago] ('Double Extra Large', 1, 1, 0)
# 2025-12-02 14:48:02,449 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,449 INFO sqlalchemy.engine.Engine [cached since 0.02051s ago] (1, 10, 1, 0)
# 2025-12-02 14:48:02,449 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,450 INFO sqlalchemy.engine.Engine [cached since 0.01922s ago] (1, 10, '2025-12-02 20:48:02.449835')
# 2025-12-02 14:48:02,450 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,450 INFO sqlalchemy.engine.Engine [cached since 0.02413s ago] ('Triple Extra Large', 1, 1, 0)
# 2025-12-02 14:48:02,451 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,451 INFO sqlalchemy.engine.Engine [cached since 0.02246s ago] (1, 11, 1, 0)
# 2025-12-02 14:48:02,451 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,452 INFO sqlalchemy.engine.Engine [cached since 0.0214s ago] (1, 11, '2025-12-02 20:48:02.451852')
# 2025-12-02 14:48:02,452 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,452 INFO sqlalchemy.engine.Engine [cached since 0.02618s ago] ('Quadruple Extra Large', 1, 1, 0)
# 2025-12-02 14:48:02,453 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,453 INFO sqlalchemy.engine.Engine [cached since 0.02457s ago] (1, 12, 1, 0)
# 2025-12-02 14:48:02,453 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,454 INFO sqlalchemy.engine.Engine [cached since 0.02333s ago] (1, 12, '2025-12-02 20:48:02.453893')
# 2025-12-02 14:48:02,454 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,454 INFO sqlalchemy.engine.Engine [cached since 0.02798s ago] ('Quintuple Extra Large', 1, 1, 0)
# 2025-12-02 14:48:02,454 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,455 INFO sqlalchemy.engine.Engine [cached since 0.02619s ago] (1, 13, 1, 0)
# 2025-12-02 14:48:02,455 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,455 INFO sqlalchemy.engine.Engine [cached since 0.02491s ago] (1, 13, '2025-12-02 20:48:02.455552')
# 2025-12-02 14:48:02,456 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,456 INFO sqlalchemy.engine.Engine [cached since 12.63s ago] ('Fit', 1, 0)
# 2025-12-02 14:48:02,456 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,456 INFO sqlalchemy.engine.Engine [cached since 0.03007s ago] ('Unisex', 2, 1, 0)
# 2025-12-02 14:48:02,457 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,457 INFO sqlalchemy.engine.Engine [cached since 0.02827s ago] (1, 17, 1, 0)
# 2025-12-02 14:48:02,457 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,457 INFO sqlalchemy.engine.Engine [cached since 0.02687s ago] (1, 17, '2025-12-02 20:48:02.457549')
# 2025-12-02 14:48:02,457 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,458 INFO sqlalchemy.engine.Engine [cached since 12.63s ago] ('Color', 1, 0)
# 2025-12-02 14:48:02,458 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,458 INFO sqlalchemy.engine.Engine [cached since 0.03193s ago] ('Yellow', 3, 1, 0)
# 2025-12-02 14:48:02,458 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,459 INFO sqlalchemy.engine.Engine [cached since 0.03015s ago] (1, 24, 1, 0)
# 2025-12-02 14:48:02,459 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,459 INFO sqlalchemy.engine.Engine [cached since 0.0288s ago] (1, 24, '2025-12-02 20:48:02.459465')
# 2025-12-02 14:48:02,459 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,460 INFO sqlalchemy.engine.Engine [cached since 12.63s ago] ('Design', 1, 0)
# 2025-12-02 14:48:02,460 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,460 INFO sqlalchemy.engine.Engine [cached since 0.03399s ago] ('Bandit Banquet', 4, 1, 0)
# 2025-12-02 14:48:02,461 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,461 INFO sqlalchemy.engine.Engine [cached since 0.03224s ago] (1, 34, 1, 0)
# 2025-12-02 14:48:02,461 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,461 INFO sqlalchemy.engine.Engine [cached since 0.03084s ago] (1, 34, '2025-12-02 20:48:02.461481')
# 2025-12-02 14:48:02,461 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,462 INFO sqlalchemy.engine.Engine [cached since 12.64s ago] ('Material', 1, 0)
# 2025-12-02 14:48:02,462 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,462 INFO sqlalchemy.engine.Engine [cached since 0.03604s ago] ('Cotton', 5, 1, 0)
# 2025-12-02 14:48:02,463 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,463 INFO sqlalchemy.engine.Engine [cached since 0.03438s ago] (1, 41, 1, 0)
# 2025-12-02 14:48:02,463 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,463 INFO sqlalchemy.engine.Engine [cached since 0.03298s ago] (1, 41, '2025-12-02 20:48:02.463656')
# 2025-12-02 14:48:02,464 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,464 INFO sqlalchemy.engine.Engine [cached since 12.64s ago] ('Scent', 1, 0)
# 2025-12-02 14:48:02,464 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,454 INFO sqlalchemy.engine.Engine [cached since 0.02798s ago] ('Quintuple Extra Large', 1, 1, 0)
# 2025-12-02 14:48:02,454 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,455 INFO sqlalchemy.engine.Engine [cached since 0.02619s ago] (1, 13, 1, 0)
# 2025-12-02 14:48:02,455 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,455 INFO sqlalchemy.engine.Engine [cached since 0.02491s ago] (1, 13, '2025-12-02 20:48:02.455552')
# 2025-12-02 14:48:02,456 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,456 INFO sqlalchemy.engine.Engine [cached since 12.63s ago] ('Fit', 1, 0)
# 2025-12-02 14:48:02,456 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,456 INFO sqlalchemy.engine.Engine [cached since 0.03007s ago] ('Unisex', 2, 1, 0)
# 2025-12-02 14:48:02,457 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,457 INFO sqlalchemy.engine.Engine [cached since 0.02827s ago] (1, 17, 1, 0)
# 2025-12-02 14:48:02,457 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:02,457 INFO sqlalchemy.engine.Engine [cached since 0.02687s ago] (1, 17, '2025-12-02 20:48:02.457549')
# 2025-12-02 14:48:02,457 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:02,458 INFO sqlalchemy.engine.Engine [cached since 12.63s ago] ('Color', 1, 0)
# ...
# 2025-12-02 14:48:03,214 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,214 INFO sqlalchemy.engine.Engine [cached since 13.39s ago] ('Material', 1, 0)
# 2025-12-02 14:48:03,204 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,205 INFO sqlalchemy.engine.Engine [cached since 0.7762s ago] (18, 1, 1, 0)
# 2025-12-02 14:48:03,206 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:03,206 INFO sqlalchemy.engine.Engine [cached since 0.7758s ago] (18, 1, '2025-12-02 20:48:03.206180')
# 2025-12-02 14:48:03,207 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,207 INFO sqlalchemy.engine.Engine [cached since 13.38s ago] ('Fit', 1, 0)
# 2025-12-02 14:48:03,207 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,208 INFO sqlalchemy.engine.Engine [cached since 0.7813s ago] ('Not Applicable', 2, 1, 0)
# 2025-12-02 14:48:03,208 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,208 INFO sqlalchemy.engine.Engine [cached since 0.7796s ago] (18, 16, 1, 0)
# 2025-12-02 14:48:03,208 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:03,209 INFO sqlalchemy.engine.Engine [cached since 0.7782s ago] (18, 16, '2025-12-02 20:48:03.208900')
# 2025-12-02 14:48:03,209 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,209 INFO sqlalchemy.engine.Engine [cached since 13.38s ago] ('Color', 1, 0)
# 2025-12-02 14:48:03,209 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,210 INFO sqlalchemy.engine.Engine [cached since 0.7833s ago] ('Gold', 3, 1, 0)
# 2025-12-02 14:48:03,210 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,210 INFO sqlalchemy.engine.Engine [cached since 0.7816s ago] (18, 31, 1, 0)
# 2025-12-02 14:48:03,210 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:03,210 INFO sqlalchemy.engine.Engine [cached since 0.7801s ago] (18, 31, '2025-12-02 20:48:03.210835')
# 2025-12-02 14:48:03,211 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,211 INFO sqlalchemy.engine.Engine [cached since 13.38s ago] ('Design', 1, 0)
# 2025-12-02 14:48:03,211 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,211 INFO sqlalchemy.engine.Engine [cached since 0.7852s ago] ('Legendary Icon', 4, 1, 0)
# 2025-12-02 14:48:03,212 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,212 INFO sqlalchemy.engine.Engine [cached since 0.7833s ago] (18, 35, 1, 0)
# 2025-12-02 14:48:03,212 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:03,212 INFO sqlalchemy.engine.Engine [cached since 0.7819s ago] (18, 35, '2025-12-02 20:48:03.212539')
# 2025-12-02 14:48:03,213 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,213 INFO sqlalchemy.engine.Engine [cached since 0.7865s ago] ('Bandit Truck Icon', 4, 1, 0)
# 2025-12-02 14:48:03,213 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,213 INFO sqlalchemy.engine.Engine [cached since 0.7847s ago] (18, 37, 1, 0)
# 2025-12-02 14:48:03,213 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:03,214 INFO sqlalchemy.engine.Engine [cached since 0.7832s ago] (18, 37, '2025-12-02 20:48:03.213895')
# 2025-12-02 14:48:03,214 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,214 INFO sqlalchemy.engine.Engine [cached since 13.39s ago] ('Material', 1, 0)
# 2025-12-02 14:48:03,214 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,214 INFO sqlalchemy.engine.Engine [cached since 0.7882s ago] ('Metal', 5, 1, 0)
# 2025-12-02 14:48:03,215 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,215 INFO sqlalchemy.engine.Engine [cached since 0.7863s ago] (18, 45, 1, 0)
# 2025-12-02 14:48:03,215 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:03,215 INFO sqlalchemy.engine.Engine [cached since 0.7849s ago] (18, 45, '2025-12-02 20:48:03.215540')
# 2025-12-02 14:48:03,216 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,216 INFO sqlalchemy.engine.Engine [cached since 13.39s ago] ('Scent', 1, 0)
# 2025-12-02 14:48:03,216 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,216 INFO sqlalchemy.engine.Engine [cached since 0.79s ago] ('Not Applicable', 6, 1, 0)
# 2025-12-02 14:48:03,216 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,217 INFO sqlalchemy.engine.Engine [cached since 0.7883s ago] (18, 49, 1, 0)
# 2025-12-02 14:48:03,217 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:03,217 INFO sqlalchemy.engine.Engine [cached since 0.7867s ago] (18, 49, '2025-12-02 20:48:03.217435')
# 2025-12-02 14:48:03,217 INFO sqlalchemy.engine.Engine COMMIT
# ✓ 234 product-feature links created!
# 2025-12-02 14:48:03,214 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,214 INFO sqlalchemy.engine.Engine [cached since 0.7882s ago] ('Metal', 5, 1, 0)
# 2025-12-02 14:48:03,215 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,215 INFO sqlalchemy.engine.Engine [cached since 0.7863s ago] (18, 45, 1, 0)
# 2025-12-02 14:48:03,215 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:03,215 INFO sqlalchemy.engine.Engine [cached since 0.7849s ago] (18, 45, '2025-12-02 20:48:03.215540')
# 2025-12-02 14:48:03,216 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.feature_type = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,216 INFO sqlalchemy.engine.Engine [cached since 13.39s ago] ('Scent', 1, 0)
# 2025-12-02 14:48:03,216 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features JOIN feature_types ON feature_types.id = features.feature_type_id
# WHERE features.name = ? AND feature_types.id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,216 INFO sqlalchemy.engine.Engine [cached since 0.79s ago] ('Not Applicable', 6, 1, 0)
# 2025-12-02 14:48:03,216 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE product_features.product_id = ? AND product_features.feature_id = ?
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:03,217 INFO sqlalchemy.engine.Engine [cached since 0.7883s ago] (18, 49, 1, 0)
# 2025-12-02 14:48:03,217 INFO sqlalchemy.engine.Engine INSERT INTO product_features (product_id, feature_id, created_at) VALUES (?, ?, ?)
# 2025-12-02 14:48:03,217 INFO sqlalchemy.engine.Engine [cached since 0.7867s ago] (18, 49, '2025-12-02 20:48:03.217435')
# 2025-12-02 14:48:03,217 INFO sqlalchemy.engine.Engine COMMIT
# ✓ 234 product-feature links created!

# %% [markdown]
# ### Step 7: Verify Migration
#
# Query the database to confirm all data was migrated correctly.

# %%
session = Session()

try:
    print("DATABASE MIGRATION SUMMARY")
    print("=" * 80)
    
    # Count records in each table
    categories_count = session.query(Category).count()
    feature_types_count = session.query(FeatureType).count()
    features_count = session.query(Feature).count()
    products_count = session.query(Product).count()
    product_features_count = session.query(ProductFeature).count()
    
    print(f"\n📊 Record Counts:")
    print(f"  Categories:       {categories_count}")
    print(f"  Feature Types:    {feature_types_count}")
    print(f"  Features:         {features_count}")
    print(f"  Products:         {products_count}")
    print(f"  Product-Features: {product_features_count}")
    
    # Show sample product with its features
    print(f"\n📦 Sample Product:")
    sample_product = session.query(Product).first()
    if sample_product:
        print(f"  Name: {sample_product.product_name}")
        print(f"  Category: {sample_product.category.category} → {sample_product.category.subcategory}")
        print(f"  Available Features:")
        
        for pf in sample_product.product_features:
            feature = pf.feature
            print(f"    - {feature.feature_type.feature_type}: {feature.name} ({feature.code})")
    
    print("\n" + "=" * 80)
    print("✓ Migration verification complete!")
    
except Exception as e:
    print(f"✗ Error verifying migration: {e}")
    raise
finally:
    session.close()
# Out:
# DATABASE MIGRATION SUMMARY
# ================================================================================
# 2025-12-02 14:48:11,516 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-02 14:48:11,520 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories) AS anon_1
# 2025-12-02 14:48:11,521 INFO sqlalchemy.engine.Engine [generated in 0.00084s] ()
# 2025-12-02 14:48:11,522 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types) AS anon_1
# 2025-12-02 14:48:11,523 INFO sqlalchemy.engine.Engine [generated in 0.00032s] ()
# 2025-12-02 14:48:11,525 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features) AS anon_1
# 2025-12-02 14:48:11,525 INFO sqlalchemy.engine.Engine [generated in 0.00070s] ()
# 2025-12-02 14:48:11,527 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products) AS anon_1
# 2025-12-02 14:48:11,520 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories) AS anon_1
# 2025-12-02 14:48:11,521 INFO sqlalchemy.engine.Engine [generated in 0.00084s] ()
# 2025-12-02 14:48:11,522 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types) AS anon_1
# 2025-12-02 14:48:11,523 INFO sqlalchemy.engine.Engine [generated in 0.00032s] ()
# 2025-12-02 14:48:11,525 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features) AS anon_1
# 2025-12-02 14:48:11,525 INFO sqlalchemy.engine.Engine [generated in 0.00070s] ()
# 2025-12-02 14:48:11,527 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products) AS anon_1
# 2025-12-02 14:48:11,527 INFO sqlalchemy.engine.Engine [generated in 0.00026s] ()
# 2025-12-02 14:48:11,529 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features) AS anon_1
# 2025-12-02 14:48:11,529 INFO sqlalchemy.engine.Engine [generated in 0.00033s] ()
#
# 📊 Record Counts:
#   Categories:       11
#   Feature Types:    6
#   Features:         52
#   Products:         18
#   Product-Features: 234
#
# 📦 Sample Product:
# 2025-12-02 14:48:11,530 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:11,530 INFO sqlalchemy.engine.Engine [generated in 0.00028s] (1, 0)
#   Name: Bandit Banquet Tee
# 2025-12-02 14:48:11,531 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.id = ?
# 2025-12-02 14:48:11,531 INFO sqlalchemy.engine.Engine [cached since 364.1s ago] (1,)
#   Category: Shirt → Tee Shirt
#   Available Features:
# 2025-12-02 14:48:11,532 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE ? = product_features.product_id
# 2025-12-02 14:48:11,533 INFO sqlalchemy.engine.Engine [generated in 0.00036s] (1,)
# 2025-12-02 14:48:11,534 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,534 INFO sqlalchemy.engine.Engine [generated in 0.00022s] (2,)
# 2025-12-02 14:48:11,534 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.id = ?
# 2025-12-02 14:48:11,535 INFO sqlalchemy.engine.Engine [cached since 364.1s ago] (1,)
#     - Size: Child Small (CS)
# 2025-12-02 14:48:11,535 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,535 INFO sqlalchemy.engine.Engine [cached since 0.001737s ago] (3,)
#     - Size: Child Medium (CM)
# 2025-12-02 14:48:11,536 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,536 INFO sqlalchemy.engine.Engine [cached since 0.002657s ago] (4,)
#     - Size: Child Large (CL)
# 2025-12-02 14:48:11,537 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,537 INFO sqlalchemy.engine.Engine [cached since 0.003443s ago] (5,)
# 2025-12-02 14:48:11,527 INFO sqlalchemy.engine.Engine [generated in 0.00026s] ()
# 2025-12-02 14:48:11,529 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features) AS anon_1
# 2025-12-02 14:48:11,529 INFO sqlalchemy.engine.Engine [generated in 0.00033s] ()
#
# 📊 Record Counts:
#   Categories:       11
#   Feature Types:    6
#   Features:         52
#   Products:         18
#   Product-Features: 234
#
# 📦 Sample Product:
# 2025-12-02 14:48:11,530 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.product_name AS products_product_name, products.category_id AS products_category_id, products.description AS products_description, products.base_price AS products_base_price, products.status AS products_status, products.created_at AS products_created_at, products.updated_at AS products_updated_at
# FROM products
#  LIMIT ? OFFSET ?
# 2025-12-02 14:48:11,530 INFO sqlalchemy.engine.Engine [generated in 0.00028s] (1, 0)
#   Name: Bandit Banquet Tee
# 2025-12-02 14:48:11,531 INFO sqlalchemy.engine.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.subcategory AS categories_subcategory, categories.created_at AS categories_created_at, categories.updated_at AS categories_updated_at
# FROM categories
# WHERE categories.id = ?
# 2025-12-02 14:48:11,531 INFO sqlalchemy.engine.Engine [cached since 364.1s ago] (1,)
#   Category: Shirt → Tee Shirt
#   Available Features:
# 2025-12-02 14:48:11,532 INFO sqlalchemy.engine.Engine SELECT product_features.id AS product_features_id, product_features.product_id AS product_features_product_id, product_features.feature_id AS product_features_feature_id, product_features.created_at AS product_features_created_at
# FROM product_features
# WHERE ? = product_features.product_id
# 2025-12-02 14:48:11,533 INFO sqlalchemy.engine.Engine [generated in 0.00036s] (1,)
# 2025-12-02 14:48:11,534 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,534 INFO sqlalchemy.engine.Engine [generated in 0.00022s] (2,)
# 2025-12-02 14:48:11,534 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.id = ?
# 2025-12-02 14:48:11,535 INFO sqlalchemy.engine.Engine [cached since 364.1s ago] (1,)
#     - Size: Child Small (CS)
# 2025-12-02 14:48:11,535 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,535 INFO sqlalchemy.engine.Engine [cached since 0.001737s ago] (3,)
#     - Size: Child Medium (CM)
# 2025-12-02 14:48:11,536 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,536 INFO sqlalchemy.engine.Engine [cached since 0.002657s ago] (4,)
#     - Size: Child Large (CL)
# 2025-12-02 14:48:11,537 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,537 INFO sqlalchemy.engine.Engine [cached since 0.003443s ago] (5,)
#     - Size: Extra Small (XS)
# 2025-12-02 14:48:11,538 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,538 INFO sqlalchemy.engine.Engine [cached since 0.004265s ago] (6,)
#     - Size: Small (S)
# 2025-12-02 14:48:11,538 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,539 INFO sqlalchemy.engine.Engine [cached since 0.005055s ago] (7,)
#     - Size: Medium (M)
# 2025-12-02 14:48:11,539 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,540 INFO sqlalchemy.engine.Engine [cached since 0.006028s ago] (8,)
#     - Size: Large (L)
# 2025-12-02 14:48:11,540 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,540 INFO sqlalchemy.engine.Engine [cached since 0.006632s ago] (9,)
#     - Size: Extra Large (XL)
# 2025-12-02 14:48:11,541 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,541 INFO sqlalchemy.engine.Engine [cached since 0.007295s ago] (10,)
#     - Size: Double Extra Large (2XL)
# 2025-12-02 14:48:11,541 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,542 INFO sqlalchemy.engine.Engine [cached since 0.007928s ago] (11,)
#     - Size: Triple Extra Large (3XL)
# 2025-12-02 14:48:11,542 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,542 INFO sqlalchemy.engine.Engine [cached since 0.008683s ago] (12,)
#     - Size: Quadruple Extra Large (4XL)
# 2025-12-02 14:48:11,543 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,543 INFO sqlalchemy.engine.Engine [cached since 0.009358s ago] (13,)
#     - Size: Quintuple Extra Large (5XL)
# 2025-12-02 14:48:11,544 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,544 INFO sqlalchemy.engine.Engine [cached since 0.01012s ago] (17,)
# 2025-12-02 14:48:11,544 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.id = ?
# 2025-12-02 14:48:11,544 INFO sqlalchemy.engine.Engine [cached since 364.1s ago] (2,)
#     - Fit: Unisex (USX)
# 2025-12-02 14:48:11,545 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,545 INFO sqlalchemy.engine.Engine [cached since 0.01142s ago] (24,)
# 2025-12-02 14:48:11,545 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.id = ?
# 2025-12-02 14:48:11,546 INFO sqlalchemy.engine.Engine [cached since 364.1s ago] (3,)
#     - Color: Yellow (YLW)
# 2025-12-02 14:48:11,546 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,546 INFO sqlalchemy.engine.Engine [cached since 0.01266s ago] (34,)
# 2025-12-02 14:48:11,547 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.id = ?
# 2025-12-02 14:48:11,547 INFO sqlalchemy.engine.Engine [cached since 364.1s ago] (4,)
#     - Design: Bandit Banquet (BDBQ)
# 2025-12-02 14:48:11,547 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
#     - Size: Extra Small (XS)
# 2025-12-02 14:48:11,538 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,538 INFO sqlalchemy.engine.Engine [cached since 0.004265s ago] (6,)
#     - Size: Small (S)
# 2025-12-02 14:48:11,538 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,539 INFO sqlalchemy.engine.Engine [cached since 0.005055s ago] (7,)
#     - Size: Medium (M)
# 2025-12-02 14:48:11,539 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,540 INFO sqlalchemy.engine.Engine [cached since 0.006028s ago] (8,)
#     - Size: Large (L)
# 2025-12-02 14:48:11,540 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,540 INFO sqlalchemy.engine.Engine [cached since 0.006632s ago] (9,)
#     - Size: Extra Large (XL)
# 2025-12-02 14:48:11,541 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,541 INFO sqlalchemy.engine.Engine [cached since 0.007295s ago] (10,)
#     - Size: Double Extra Large (2XL)
# 2025-12-02 14:48:11,541 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,542 INFO sqlalchemy.engine.Engine [cached since 0.007928s ago] (11,)
#     - Size: Triple Extra Large (3XL)
# 2025-12-02 14:48:11,542 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,542 INFO sqlalchemy.engine.Engine [cached since 0.008683s ago] (12,)
#     - Size: Quadruple Extra Large (4XL)
# 2025-12-02 14:48:11,543 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,543 INFO sqlalchemy.engine.Engine [cached since 0.009358s ago] (13,)
#     - Size: Quintuple Extra Large (5XL)
# 2025-12-02 14:48:11,544 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,544 INFO sqlalchemy.engine.Engine [cached since 0.01012s ago] (17,)
# 2025-12-02 14:48:11,544 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.id = ?
# 2025-12-02 14:48:11,544 INFO sqlalchemy.engine.Engine [cached since 364.1s ago] (2,)
#     - Fit: Unisex (USX)
# 2025-12-02 14:48:11,545 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,545 INFO sqlalchemy.engine.Engine [cached since 0.01142s ago] (24,)
# 2025-12-02 14:48:11,545 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.id = ?
# 2025-12-02 14:48:11,546 INFO sqlalchemy.engine.Engine [cached since 364.1s ago] (3,)
#     - Color: Yellow (YLW)
# 2025-12-02 14:48:11,546 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,546 INFO sqlalchemy.engine.Engine [cached since 0.01266s ago] (34,)
# 2025-12-02 14:48:11,547 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.id = ?
# 2025-12-02 14:48:11,547 INFO sqlalchemy.engine.Engine [cached since 364.1s ago] (4,)
#     - Design: Bandit Banquet (BDBQ)
# 2025-12-02 14:48:11,547 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,547 INFO sqlalchemy.engine.Engine [cached since 0.01365s ago] (41,)
# 2025-12-02 14:48:11,548 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.id = ?
# 2025-12-02 14:48:11,548 INFO sqlalchemy.engine.Engine [cached since 364.1s ago] (5,)
#     - Material: Cotton (CTN)
# 2025-12-02 14:48:11,548 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,548 INFO sqlalchemy.engine.Engine [cached since 0.01474s ago] (49,)
# 2025-12-02 14:48:11,549 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.id = ?
# 2025-12-02 14:48:11,549 INFO sqlalchemy.engine.Engine [cached since 364.1s ago] (6,)
#     - Scent: Not Applicable (STNAN)
#
# ================================================================================
# ✓ Migration verification complete!
# 2025-12-02 14:48:11,549 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-12-02 14:48:11,547 INFO sqlalchemy.engine.Engine [cached since 0.01365s ago] (41,)
# 2025-12-02 14:48:11,548 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.id = ?
# 2025-12-02 14:48:11,548 INFO sqlalchemy.engine.Engine [cached since 364.1s ago] (5,)
#     - Material: Cotton (CTN)
# 2025-12-02 14:48:11,548 INFO sqlalchemy.engine.Engine SELECT features.id AS features_id, features.feature_type_id AS features_feature_type_id, features.code AS features_code, features.name AS features_name, features.description AS features_description, features.sort_order AS features_sort_order, features.is_active AS features_is_active, features.created_at AS features_created_at, features.updated_at AS features_updated_at
# FROM features
# WHERE features.id = ?
# 2025-12-02 14:48:11,548 INFO sqlalchemy.engine.Engine [cached since 0.01474s ago] (49,)
# 2025-12-02 14:48:11,549 INFO sqlalchemy.engine.Engine SELECT feature_types.id AS feature_types_id, feature_types.feature_type AS feature_types_feature_type, feature_types.display_order AS feature_types_display_order, feature_types.is_required AS feature_types_is_required, feature_types.created_at AS feature_types_created_at
# FROM feature_types
# WHERE feature_types.id = ?
# 2025-12-02 14:48:11,549 INFO sqlalchemy.engine.Engine [cached since 364.1s ago] (6,)
#     - Scent: Not Applicable (STNAN)
#
# ================================================================================
# ✓ Migration verification complete!
# 2025-12-02 14:48:11,549 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# ### Table 1: Categories
#
# **Purpose**: Store product categories and subcategories
#
# | Column | Type | Constraints | Description |
# |--------|------|-------------|-------------|
# | id | INTEGER | PRIMARY KEY, AUTOINCREMENT | Unique identifier |
# | category | VARCHAR(100) | NOT NULL | Main category (e.g., "Apparel") |
# | subcategory | VARCHAR(100) | | Subcategory (e.g., "T-Shirts") |
# | created_at | TIMESTAMP | DEFAULT CURRENT_TIMESTAMP | Record creation time |
# | updated_at | TIMESTAMP | DEFAULT CURRENT_TIMESTAMP | Last update time |
#
# **Indexes**:
# - Index on (category, subcategory) for lookup performance
#
# **Notes**:
# - Add any additional fields you need here

# %% [markdown]
# ### Additional Tables to Consider
#
# **What else do you need to track?**
#
# Ideas:
# - **Suppliers**: Vendor information
# - **Images**: Product/SKU images (URLs or paths)
# - **Pricing History**: Track price changes over time
# - **Inventory Transactions**: Log inventory changes
# - **Sales Channels**: Where products are sold (website, store, etc.)
# - **Product Relationships**: Bundles, variants, related products
# - **Custom Fields**: Flexible metadata storage
#
# **Tell me what additional columns or tables you want to add!**

# %% [markdown]
# ### Table 7: SKU Features
#
# **Purpose**: Link each SKU to its specific feature combination
#
# | Column | Type | Constraints | Description |
# |--------|------|-------------|-------------|
# | id | INTEGER | PRIMARY KEY, AUTOINCREMENT | Unique identifier |
# | sku_id | INTEGER | FOREIGN KEY → skus.id | The SKU |
# | feature_id | INTEGER | FOREIGN KEY → features.id | Feature in this SKU |
# | created_at | TIMESTAMP | DEFAULT CURRENT_TIMESTAMP | Record creation time |
#
# **Indexes**:
# - Index on sku_id
# - Index on feature_id
#
# **Constraints**:
# - UNIQUE(sku_id, feature_id) - no duplicate features per SKU
#
# **Notes**:
# - This allows querying all SKUs with a specific feature (e.g., "all Black products")

# %% [markdown]
# ### Table 6: SKUs
#
# **Purpose**: Store generated SKUs with all their feature combinations
#
# | Column | Type | Constraints | Description |
# |--------|------|-------------|-------------|
# | id | INTEGER | PRIMARY KEY, AUTOINCREMENT | Unique identifier |
# | sku | VARCHAR(100) | NOT NULL, UNIQUE | Generated SKU code |
# | product_id | INTEGER | FOREIGN KEY → products.id | Base product |
# | batch_name | VARCHAR(200) | | Batch identifier (for tracking) |
# | price | DECIMAL(10,2) | | SKU-specific price (if different from base) |
# | inventory_qty | INTEGER | DEFAULT 0 | Current inventory count |
# | status | VARCHAR(20) | DEFAULT 'active' | active/inactive/discontinued |
# | generated_at | TIMESTAMP | DEFAULT CURRENT_TIMESTAMP | When SKU was generated |
# | updated_at | TIMESTAMP | DEFAULT CURRENT_TIMESTAMP | Last update time |
#
# **Indexes**:
# - Index on sku (already implied by UNIQUE)
# - Index on product_id
# - Index on batch_name
# - Index on status
#
# **Notes**:
# - What other SKU-level fields do you need? (weight, dimensions, UPC, etc.?)

# %% [markdown]
# ### Table 5: Product Features
#
# **Purpose**: Link products to their available features (which colors/sizes apply to which products)
#
# | Column | Type | Constraints | Description |
# |--------|------|-------------|-------------|
# | id | INTEGER | PRIMARY KEY, AUTOINCREMENT | Unique identifier |
# | product_id | INTEGER | FOREIGN KEY → products.id | Product this applies to |
# | feature_id | INTEGER | FOREIGN KEY → features.id | Available feature |
# | created_at | TIMESTAMP | DEFAULT CURRENT_TIMESTAMP | Record creation time |
#
# **Indexes**:
# - Index on product_id
# - Index on feature_id
#
# **Constraints**:
# - UNIQUE(product_id, feature_id) - no duplicate feature assignments
#
# **Notes**:
# - This junction table defines which features are valid for each product

# %% [markdown]
# ### Table 4: Features
#
# **Purpose**: Store individual feature values (specific colors, sizes, etc.)
#
# | Column | Type | Constraints | Description |
# |--------|------|-------------|-------------|
# | id | INTEGER | PRIMARY KEY, AUTOINCREMENT | Unique identifier |
# | feature_type_id | INTEGER | FOREIGN KEY → feature_types.id | Type of feature |
# | code | VARCHAR(20) | NOT NULL | Short code for SKU (e.g., "BLK", "XL") |
# | name | VARCHAR(100) | NOT NULL | Display name (e.g., "Black", "Extra Large") |
# | description | TEXT | | Additional details |
# | sort_order | INTEGER | | Order within feature type |
# | is_active | BOOLEAN | DEFAULT TRUE | Whether feature is currently available |
# | created_at | TIMESTAMP | DEFAULT CURRENT_TIMESTAMP | Record creation time |
# | updated_at | TIMESTAMP | DEFAULT CURRENT_TIMESTAMP | Last update time |
#
# **Indexes**:
# - Index on (feature_type_id, code)
# - Index on is_active
#
# **Constraints**:
# - UNIQUE(feature_type_id, code) - no duplicate codes within same feature type
#
# **Notes**:
# - Any additional feature attributes you want to track?

# %% [markdown]
# ### Table 3: Feature Types
#
# **Purpose**: Define types of features (Color, Size, Design, etc.)
#
# | Column | Type | Constraints | Description |
# |--------|------|-------------|-------------|
# | id | INTEGER | PRIMARY KEY, AUTOINCREMENT | Unique identifier |
# | feature_type | VARCHAR(50) | NOT NULL, UNIQUE | e.g., "Color", "Size", "Design" |
# | display_order | INTEGER | | Order for display purposes |
# | is_required | BOOLEAN | DEFAULT FALSE | Whether feature is required for SKU |
# | created_at | TIMESTAMP | DEFAULT CURRENT_TIMESTAMP | Record creation time |
#
# **Notes**:
# - This allows us to add new feature types without schema changes

# %% [markdown]
# ### Table 2: Products
#
# **Purpose**: Store base product models (before permutations)
#
# | Column | Type | Constraints | Description |
# |--------|------|-------------|-------------|
# | id | INTEGER | PRIMARY KEY, AUTOINCREMENT | Unique identifier |
# | product_name | VARCHAR(200) | NOT NULL, UNIQUE | Product model name |
# | category_id | INTEGER | FOREIGN KEY → categories.id | Link to category |
# | description | TEXT | | Product description |
# | base_price | DECIMAL(10,2) | | Base price (optional) |
# | status | VARCHAR(20) | DEFAULT 'active' | active/inactive/discontinued |
# | created_at | TIMESTAMP | DEFAULT CURRENT_TIMESTAMP | Record creation time |
# | updated_at | TIMESTAMP | DEFAULT CURRENT_TIMESTAMP | Last update time |
#
# **Indexes**:
# - Index on product_name
# - Index on category_id
# - Index on status
#
# **Notes**:
# - What other product-level fields do you need?

# %% [markdown]
# ### Draft Schema in Mermaid

# %% [markdown]
# **See the rendered ER diagram in `docs/schema-diagram.md`**
#
# Open that file and press `Cmd+Shift+V` to view the Mermaid diagram with all table relationships.

# %% [markdown]
# ## Phase 2: Data Migration

# %% [markdown]
# ## Phase 3: SKU Generation Logic

# %% [markdown]
# ## Phase 4: PostgreSQL Preparation
